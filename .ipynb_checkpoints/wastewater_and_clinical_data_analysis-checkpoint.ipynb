# %% [markdown]
# # Import modules and authenticate

# %%
#set limit when und
# lim=0.1

#google drive authorize AND googlesheets4 authorize-- must create a project under google API and then download credentials
#see authentication section in the following article
#https://medium.com/@bretcameron/how-to-use-the-google-drive-api-with-javascript-57a6cc9e5262
#Note: need to open a service account and extract .json credentials in the API console, approve Google Drive API, then share the service account email address with the sheet of interest
path_j='/Users/owner/Desktop/Berkeley_Work/Projects/2017_San_Diego/June 2018_Data_Analysis/access-via-jupiter-notebook-d18b3ab0993b.json' #lauren's


#need  to do the following  in the activated virtual environment in your terminal
# pip install gspread
# pip install oauth2client
# pip install outliers
# pip install plotnine
# pip install scikit-misc
# pip install outlier_utils
# pip install pandas
# pip  install numpy
# pip install sklearn
# pip install geopandas
# pip install scikit_posthocs
# pip install folium
# pip install plotly_express
# pip install adjustText
# pip install contextily

# %%
#system
import warnings
import sys
import subprocess
import pkg_resources
import os
from os import path
from datetime import date

#data wrangling
import gspread
from oauth2client.service_account import ServiceAccountCredentials

#stats
import pandas as pd
import numpy as np
import math
from pandas.api.types import CategoricalDtype
from statsmodels.tsa.stattools import grangercausalitytests
# import scikit_posthocs as sp

#scipy
from scipy import stats as sci
from scipy.stats import linregress
from scipy.stats.mstats import gmean
from scipy.stats import gstd
from scipy.optimize import curve_fit
# from scipy.interpolate import interp1d

#sklearn related
from sklearn.linear_model import LinearRegression
from sklearn.utils import resample as bootstrap

#plotting
from plotnine import *
import matplotlib
from matplotlib import cm
import matplotlib.pyplot as mplt
# %matplotlib inline
from mizani.formatters import scientific_format
from pylab import * #colormap extraction


#Set up Google drive access and sheets manipulation
scope = ['https://spreadsheets.google.com/feeds']
credentials = ServiceAccountCredentials.from_json_keyfile_name(path_j, scope)


#Authorize credentials and open master sampling table using its URL
gc = gspread.authorize(credentials)
# routine= gc.open_by_url('https://docs.google.com/spreadsheets/d/163xXZnJjh0LdryxrDhuYxgzHB_IY7Jaew3DpYzoNs9Q/edit#gid=1255279898')
# qpcr=gc.open_by_url('https://docs.google.com/spreadsheets/d/1TzZcB2p55BuG5FbXAA44EFoe8BdRapGyDaVR4hx9NXU/edit#gid=1689469809')
import skmisc
import outliers


#urls
samples_url = 'https://docs.google.com/spreadsheets/d/1BROD37xHS0MUmngW8b0-017CMI-MUPs6yUhWZacRBVM/edit#gid=428335760'
qpcr_url = 'https://docs.google.com/spreadsheets/d/1_JRWgH8AJBU8IcxWCmI2Gr7aYlXr0AhKHgVVGW8PXio/edit#gid=1689469809'

#sheets
rna_tab = 'sample_inventory'
ww_tab='site_lookup'
facility_lookup='site_lookup' #from Hannah: why are ww_tab and facility_lookup the same?
qpcr_results_tab = 'QuantStudio_raw_data'
qpcr_plates_tab = 'Plate_info'
cases_tab='casedata'
chem_data = 'metadata'
cc_data_tab='Contra Costa County public case data (4S)'
master="master_curves"

# read in custom modules
from read_gsheets import * 
from reprocess_qpcr import *
from calculations import *
from qa_qc import *

#geo work
import geopandas as gpd
from shapely.geometry import Point
import folium
import plotly_express as px
from geopandas import GeoDataFrame
import adjustText as aT
import contextily as ctx

#following this https://machinelearningmastery.com/gentle-introduction-autocorrelation-partial-autocorrelation/
#https://towardsdatascience.com/granger-causality-and-vector-auto-regressive-model-for-time-series-forecasting-3226a64889a6
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller

def augmented_dickey_fuller_statistics(time_series):
    result = adfuller(time_series.values)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# %%
#plot nine relevant code

#made this by editing code from here https://gist.github.com/AllenDowney/818f6153ef316aee80467c51faee80f8
import statsmodels.api as sm
from contextlib import suppress
smlowess = sm.nonparametric.lowess

from skmisc.loess import loess as loess_klass

# import warnings
# from contextlib import suppress
# a=a.sort_values("date_sampling")

def pnlowess(y,x, **params):
    for k in ('is_sorted', 'return_sorted'):
        with suppress(KeyError):
            del params['method_args'][k]
            warnings.warn(
                "Smoothing method argument: {}, "
                "has been ignored.".format(k)
            )

    result = smlowess(y, x,
                      frac=params['span'],
                      is_sorted=True,
                      **params['method_args'])
    data = pd.DataFrame({
        'x': result[:, 0],
        'y': result[:, 1]})
    return(data)
    

    
# def skloess(data, xseq, **params):
#     try:
#         from skmisc.loess import loess as loess_klass
#     except ImportError:
#         raise PlotnineError(
#             "For loess smoothing, install 'scikit-misc'")

#     try:
#         weights = data['weight']
#     except KeyError:
#         weights = None

#     kwargs = params['method_args']

#     extrapolate = (min(xseq) < min(data['x']) or
#                    max(xseq) > max(data['x']))
#     if 'surface' not in kwargs and extrapolate:
#         # Creates a loess model that allows extrapolation
#         # when making predictions
#         kwargs['surface'] = 'direct'
#         warnings.warn(
#             "Making prediction outside the data range, "
#             "setting loess control parameter `surface='direct'`.",
#             PlotnineWarning)

#     if 'span' not in kwargs:
#         kwargs['span'] = params['span']

#     lo = loess_klass(data['x'], data['y'], weights, **kwargs)
#     lo.fit()

#     data = pd.DataFrame({'x': xseq})

#     if params['se']:
#         alpha = 1 - params['level']
#         prediction = lo.predict(xseq, stderror=True)
#         ci = prediction.confidence(alpha=alpha)
#         data['se'] = prediction.stderr
#         data['ymin'] = ci.lower
#         data['ymax'] = ci.upper
#     else:
#         prediction = lo.predict(xseq, stderror=False)

#     data['y'] = prediction.values

#     return data

def make_loess(series, wk):
    endog = series.values
    exog = series.index.values
    tot=len(endog)
    fr=wk/tot

    smooth = smlowess(endog, exog,frac=fr, is_sorted=True) #is_sorted needs to be true for dates
    index, data = np.transpose(smooth)
    
    return pd.Series(data, index=pd.to_datetime(index))

# def make_loess(series, wk):
#     endog = series.values
#     exog = series.index.values
#     tot=len(endog)
#     fr=wk/tot

#     lo = loess_klass(endog, exog,span=fr) 
#     lo.fit()
#     prediction = lo.predict(exog, stderror=False)
    
#     return pd.Series(prediction.values, index=pd.to_datetime(exog))

#prove that the function from the code is the same
# a=qpcr_long_dict["K_K_INF"].copy()
# a=a[~np.isnan(a.value)]

# t=["N1_int"]
# a=a[a.Target.isin(t)]
# a['ymax']=a.value * a.gstd
# a['ymin']=a.value / a.gstd

# data=pnlowess(a.value, a.date_sampling,span=alpha, method_args= {})
# data.x=pd.to_datetime(data.x)


# lo = loess_klass(a.value, a.date_sampling,span=alpha) 
# lo.fit()
# prediction = lo.predict(a.date_sampling,  stderror=False)

# %%
#saving figures and tables
dir_c='/Users/owner/Desktop/Berkeley_Work/data_analysis/county_plots'
dir_l='/Users/owner/Desktop/Berkeley_Work/data_analysis/LTM_plots'
dir_test='/Users/owner/Desktop/'
pd.set_option('display.float_format', '{:.2E}'.format)

# %%
#testing code

# master_curve=read_gsheet(gc, qpcr_url, master)
# master_curve.LoD_Cq=pd.to_numeric(master_curve.LoD_Cq)
# master_curve.m=pd.to_numeric(master_curve.m)
# master_curve.b=pd.to_numeric(master_curve.b)
# master_curve.LoD_quantity=pd.to_numeric(master_curve.LoD_quantity)
# master_curve.lowest_quantity=pd.to_numeric(master_curve.lowest_quantity)
# qpcr_raw = read_qpcr_data(gc, qpcr_url, qpcr_results_tab, qpcr_plates_tab)
# plates=[ 68, 85, 86, 87,88, 91, 92, 93, 94, 95, 96, 99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121, 123, 124,125,126 ]
# qpcr_raw=qpcr_raw[qpcr_raw.plate_id.isin(plates)].copy()
# qpcr_processed, std_curve_df, dilution_expts_df,raw_outliers_flagged_df, control_df = process_qpcr_raw(qpcr_raw, 'grubbs_only', master=master_curve, use_master_curve=True)

# %% [markdown]
# # Load Data

# %%
# load data for plotting trends over time
# read in data
sample_data = read_sample_data(gc, samples_url, rna_tab, facility_lookup)
copy_sd=sample_data

sample_data["RNA_yield_quantification"]=np.nan
sample_data["DNA_yield_quantification"]=np.nan
sample_data.loc[sample_data.RNA_ng_ul_qubit_all=='<5','RNA_yield_quantification']='below quantification limit'
sample_data.loc[(sample_data.RNA_ng_ul_qubit_all!="")&(sample_data.RNA_ng_ul_qubit_all!='<5'),'RNA_yield_quantification']='quantifiable'
sample_data.loc[sample_data.RNA_ng_ul_qubit_all=='<5','RNA_ng_ul_qubit_all']=2.5
sample_data.loc[sample_data.DNA_ng_ul_qubit_all=='<0.05','DNA_yield_quantification']='below quantification limit'
sample_data.loc[((sample_data.DNA_ng_ul_qubit_all!=""))&(sample_data.DNA_ng_ul_qubit_all!='<0.05'),'DNA_yield_quantification']='quantifiable'
sample_data.loc[sample_data.DNA_ng_ul_qubit_all=='<0.05','DNA_ng_ul_qubit_all']=0.025

#get RNA data into good form
sample_data['elution_vol_ul']=pd.to_numeric(sample_data.elution_vol_ul)
sample_data['weight_vol_extracted_ml']=pd.to_numeric(sample_data.weight_vol_extracted_ml)
sample_data['RNA_ng_ul_qubit_all']=pd.to_numeric(sample_data.RNA_ng_ul_qubit_all)
sample_data['DNA_ng_ul_qubit_all']=pd.to_numeric(sample_data.DNA_ng_ul_qubit_all)
sample_data['RNA_yield_ext']=(sample_data.RNA_ng_ul_qubit_all*sample_data.elution_vol_ul)
sample_data['DNA_yield_ext']=(sample_data.DNA_ng_ul_qubit_all*sample_data.elution_vol_ul)
sample_data['RNA_yield']=(sample_data.RNA_ng_ul_qubit_all*sample_data.elution_vol_ul)/sample_data.weight_vol_extracted_ml
sample_data['DNA_yield']=(sample_data.DNA_ng_ul_qubit_all*sample_data.elution_vol_ul)/sample_data.weight_vol_extracted_ml
sample_data['date_sampling']=pd.to_datetime(sample_data['date_sampling'])

master_curve=read_gsheet(gc, qpcr_url, master)
master_curve.LoD_Cq=pd.to_numeric(master_curve.LoD_Cq)
master_curve.m=pd.to_numeric(master_curve.m)
master_curve.b=pd.to_numeric(master_curve.b)
master_curve.LoD_quantity=pd.to_numeric(master_curve.LoD_quantity)
master_curve.lowest_quantity=pd.to_numeric(master_curve.lowest_quantity)

# plotting LoD lines for each plot
master_curve["LoD_gc_per_L"]= (master_curve.lowest_quantity/5)*1000*200/50
N1_LoD=master_curve.loc[master_curve.Target=="N1", "LoD_gc_per_L"].item()
S18_LoD=master_curve.loc[master_curve.Target=="18S", "LoD_gc_per_L"].item()
PMMoV_LoD=master_curve.loc[master_curve.Target=="PMMoV", "LoD_gc_per_L"].item()
C_LoD=master_curve.loc[master_curve.Target=="crAss", "LoD_gc_per_L"].item()
bact_LoD=master_curve.loc[master_curve.Target=="bact", "LoD_gc_per_L"].item()

#qpcr data
qpcr_raw = read_qpcr_data(gc, qpcr_url, qpcr_results_tab, qpcr_plates_tab)
plates=[ 68, 85, 86, 87,88, 91, 92, 93, 94, 95, 96, 99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121, 123, 124,125,126,127 ]
qpcr_raw=qpcr_raw[qpcr_raw.plate_id.isin(plates)].copy()
qpcr_processed, std_curve_df, dilution_expts_df,raw_outliers_flagged_df, control_df = process_qpcr_raw(qpcr_raw, 'grubbs_only', master=master_curve, use_master_curve=True)


# merge with sample data
qpcr_averaged = qpcr_processed.merge(sample_data, how='left', left_on='Sample', right_on='sample_id')
qpcr_averaged = qpcr_averaged[(qpcr_averaged.Sample != 'NTC') &
                              (qpcr_averaged.Target != 'Xeno') &
                              (qpcr_averaged.inhibition_testing == "N")] # Remove spike and dilute inhibition testing from qPCR averaged
# qpcr_averaged.loc[np.isnan(qpcr_averaged.Quantity_mean)&(qpcr_averaged.is_undetermined_count==3), "Quantity_mean"]=lim

# calculations
qpcr_averaged['gc_per_L'] = calculate_gc_per_l(qpcr_averaged) # get gc/L
qpcr_averaged = normalize_to_pmmov(qpcr_averaged)
# qpcr_averaged = get_GFP_recovery(qpcr_averaged)  # this converts dates to numeric somehow
qpcr_averaged_merged= get_extraction_control(qpcr_averaged)


# test inhibition
qpcr_averaged_merged, xeno_inhib_full,xeno_control=xeno_inhibition_test(raw_outliers_flagged_df,qpcr_averaged_merged)
xeno_inhib=xeno_inhib_full.merge(sample_data, left_on='Sample', right_on='sample_id',  how='left').copy()
xeno_inhib=xeno_inhib[(xeno_inhib['batch'].str.contains("B", na=False))].copy()
x_plates=xeno_inhib.plate_id.unique()
xeno_control=xeno_control[xeno_control.plate_id.isin(x_plates)].copy()

#remove pop up lab batches
qpcr_averaged_merged=qpcr_averaged_merged[(qpcr_averaged_merged['batch'].str.contains("B", na=False))].copy()
nI=["RV","SD2","SRWS","SR"]
qpcr_averaged_merged=qpcr_averaged_merged[~qpcr_averaged_merged.interceptor.isin(nI)].copy()

#control df
control_df.loc[control_df.Task!="Negative Control", "Task"]="PBS control"
c_plates=qpcr_averaged_merged.plate_id.unique()
control_df=control_df[(control_df.plate_id > 84)|(control_df.plate_id.isin(c_plates))].copy()
# control_df.loc[np.isnan(control_df.Quantity_mean)&(control_df.is_undetermined_count==3), "Quantity_mean"]=0
# Out:
# PMMoV
#    Quantity  Cq_mean  negatives  total   fr_pos
# 0  1.00E+02 3.64E+01          0     12 1.00E+00
# 1  1.00E+03 3.33E+01          0     12 1.00E+00
# 2  1.00E+04 2.98E+01          0     12 1.00E+00
# 3  1.00E+05 2.64E+01          0     12 1.00E+00
# 4  1.00E+06 2.26E+01          0     12 1.00E+00
# 5  1.00E+07 1.90E+01          0     12 1.00E+00
# 6  1.00E+08 1.57E+01          0     12 1.00E+00
# N1
#     Quantity  Cq_mean  negatives  total   fr_pos
# 0   3.12E-01 3.83E+01          8      9 1.11E-01
# 1   6.25E-01 3.83E+01          8      9 1.11E-01
# 2   1.25E+00 3.83E+01          7      9 2.22E-01
# 3   2.50E+00 3.76E+01          3      9 6.67E-01
# 4   5.00E+00 3.73E+01         17     50 6.60E-01
# 5   1.00E+01 3.64E+01          5     48 8.96E-01
# 6   2.00E+01 3.55E+01          1     51 9.80E-01
# 7   1.00E+02 3.28E+01          0     51 1.00E+00
# 8   1.00E+03 2.94E+01          0     51 1.00E+00
# 9   1.00E+04 2.59E+01          0     51 1.00E+00
# ...

# %%
cols=["Sample","plate_id","Target","raw_Cq_values", "sub_Cq_values","outlier_Cq_values","Quantity_mean", "blod_master_curve"]
len(qpcr_processed[np.isnan(qpcr_processed.Cq_mean)][cols].sort_values(["Target","Sample"]))
# qpcr_processed[np.isnan(qpcr_processed.Cq_mean)][cols].sort_values(["Target","Sample"])
# Out:
# 0

# %%
# qpcr_processed[cols].sort_values("Cq_mean")
len(qpcr_processed[qpcr_processed.blod_master_curve==True]) #60 are samples
# qpcr_processed[qpcr_processed.blod_master_curve==True][cols].sort_values(["Target","Sample"])[81:100]
# Out:
# 97

# %%
# load case data

e_start=pd.to_datetime("2020-04-14")
e_end=pd.to_datetime("2020-10-16")
low=5.5#For Alameda and contra costa county, we received values masked below 11

#Central San Case Data
path='casedata/COVID_CA_Central_San_data_Contra_Costa.csv'
cc_cases=pd.read_csv(path)
cc_cases.date_sampling=pd.to_datetime(cc_cases.date_sampling)
cc_cases.total_tests=pd.to_numeric(cc_cases.total_tests)
cc_cases.new_cases=pd.to_numeric(cc_cases.new_cases)
cc_cases=cc_cases[["date_sampling","new_cases","active_cases","total_tests"]].copy()
cc_cases.columns=["date_sampling","new_cases_Ep_old","active_cases","total_tests"]
cc_cases[["fourteen_day_moving_total_new_cases","active_cases","released_while_active","resolved","deaths", "seven_day_moving_total_active_cases"]]=  np.nan
cc_cases["interceptor"]="INF"
cc_cases["utility"]="K"
cc_cases["population"]="need to merge later"
cc_cases["sample_code"]= "K_K_INF"

#seven-day moving totals
cc_cases=cc_cases.loc[(cc_cases.date_sampling > e_start)& (cc_cases.date_sampling < e_end),]
cc_cases=cc_cases.set_index("date_sampling")
cc_cases=cc_cases.sort_index()
cc_cases['seven_day_moving_total_new_cases_Ep_old']=cc_cases.rolling(window=7, axis=1)['new_cases_Ep_old'].sum()
cc_cases=cc_cases.reset_index()


#add additional censored dates to cc_data
path='casedata/CC_Cases_By_Date - CC_Cases_By_Date.csv'
cc_cases_extra=pd.read_csv(path)
cc_cases_extra.Date=pd.to_datetime(cc_cases_extra.Date)
cc_cases_extra=cc_cases_extra.loc[(cc_cases_extra.Date > e_start)& (cc_cases_extra.Date < e_end),]
cc_cases_extra=cc_cases_extra.pivot(index=['Date'], columns='DateType', values='N').reset_index()
cc_cases_extra.columns=['date_sampling', 'new_cases_Ep', 'new_cases_Col', 'new_cases']
cc_cases_extra.loc[np.isnan(cc_cases_extra.new_cases_Ep),"new_cases_Ep"]= 0.79
cc_cases_extra.loc[np.isnan(cc_cases_extra.new_cases_Col),"new_cases_Col"]=0.79
cc_cases_extra.loc[np.isnan(cc_cases_extra.new_cases),"new_cases"]=0.79
cc_cases_extra=cc_cases_extra.set_index("date_sampling")
cc_cases_extra=cc_cases_extra.sort_index()
cc_cases_extra=cc_cases_extra.resample('1d').fillna("pad")
cc_cases_extra['seven_day_moving_total_new_cases_Ep']=cc_cases_extra.rolling(window=7, axis=1)['new_cases_Ep'].sum()
cc_cases_extra['seven_day_moving_total_new_cases_Col']=cc_cases_extra.rolling(window=7, axis=1)['new_cases_Col'].sum()
cc_cases_extra['seven_day_moving_total_new_cases']=cc_cases_extra.rolling(window=7, axis=1)['new_cases'].sum()
cc_cases_extra=cc_cases_extra.reset_index()

# #merge more stuff cc
cc_cases=cc_cases.merge(cc_cases_extra, how='left', on='date_sampling')

#prison case data
path='casedata/COVID_CA_prison_data_201207.csv'
prison_cases=pd.read_csv(path)
prison_cases.Date=pd.to_datetime(prison_cases.Date)

#SQ
sq_cases=prison_cases.loc[prison_cases.InstitutionName == "San Quentin State Prison (SQ)",:].copy()
sq_cases.index=sq_cases.Date
sq_cases=sq_cases.drop(["InstitutionName","Latitude","Longitude","Date"], axis=1)
no_roll=["DistinctPatientsTested","TotalActive"]
sq_cases.loc[:,~sq_cases.columns.isin(no_roll) ]=sq_cases.loc[:,~sq_cases.columns.isin(no_roll) ].diff(periods=1, axis=0)#new cases per day
sq_cases=sq_cases.reset_index()
sq_cases.columns=["date_sampling","new_cases","active_cases","released_while_active","resolved","deaths","total_tests"]
sq_cases["interceptor"]="SQ"
sq_cases["utility"]="B"
sq_cases["population"]="need to merge later"
sq_cases[["seven_day_moving_total_new_cases","fourteen_day_moving_total_new_cases", "new_cases_Ep_old", 'seven_day_moving_total_new_cases_Ep_old', "new_cases_Ep", 'seven_day_moving_total_new_cases_Ep', "new_cases_Col", 'seven_day_moving_total_new_cases_Col']]=np.nan
sq_cases["sample_code"]='B_B_SQ'
#seven day moving totals
sq_cases=sq_cases.loc[(sq_cases.date_sampling > e_start)& (sq_cases.date_sampling < e_end),]
sq_cases=sq_cases.set_index("date_sampling")
sq_cases=sq_cases.sort_index()
sq_cases['seven_day_moving_total_new_cases']=sq_cases.rolling(window=7, axis=1)['new_cases'].sum()
sq_cases['seven_day_moving_total_active_cases']=sq_cases.rolling(window=7, axis=1)['active_cases'].sum()
sq_cases=sq_cases.reset_index()

#EBMUD new cases per day comes from 2 counties CC compiled data  for N and the S,A is alameda
path='casedata/COVID_CA_EBMUD_data_Alameda.csv'
ebmud_alameda_cases=pd.read_csv(path)
ebmud_alameda_cases.date_sampling=pd.to_datetime(ebmud_alameda_cases.date_sampling)
ebmud_alameda_cases=ebmud_alameda_cases.loc[(ebmud_alameda_cases.date_sampling > e_start)& (ebmud_alameda_cases.date_sampling < e_end),]
ebmud_alameda_cases.loc[ebmud_alameda_cases.seven_day_moving_total_new_cases=="<11", "seven_day_moving_total_new_cases"]= low 
ebmud_alameda_cases.seven_day_moving_total_new_cases=pd.to_numeric(ebmud_alameda_cases.seven_day_moving_total_new_cases)
ebmud_alameda_cases.loc[ebmud_alameda_cases.new_cases=="<11", "new_cases"]= low
ebmud_alameda_cases.new_cases=pd.to_numeric(ebmud_alameda_cases.new_cases)
ebmud_alameda_cases=ebmud_alameda_cases[ebmud_alameda_cases.interceptor != "N49"].copy() #this is only half the info contra costa gave us the full dataset
ebmud_alameda_cases["fourteen_day_moving_total_new_cases"]=np.nan

# #Contra Costa county gave us full N interceptor cases including both counties
path='casedata/Combined_NInterceptor_Covid_Counts.csv'
n_cases=pd.read_csv(path)
n_cases.columns=["date_sampling","fourteen_day_moving_total_new_cases"]
n_cases.loc[np.isnan(n_cases.fourteen_day_moving_total_new_cases),"fourteen_day_moving_total_new_cases"]= low
n_cases.date_sampling=pd.to_datetime(n_cases.date_sampling)
n_cases=n_cases.set_index("date_sampling")
n_cases=n_cases.sort_index()
n_cases=n_cases.resample('1d').fillna("pad")
n_cases=n_cases.reset_index()
n_cases=n_cases.loc[(n_cases.date_sampling > e_start)& (ebmud_alameda_cases.date_sampling < e_end),]
n_cases['new_cases']=np.nan
n_cases['seven_day_moving_total_new_cases']=np.nan
n_cases['interceptor']='N49'


#combine all ebmud data
ebmud_cases=ebmud_alameda_cases.append(n_cases)
ebmud_cases.new_cases=pd.to_numeric(ebmud_cases.new_cases)
ebmud_cases.columns
ebmud_cases[["active_cases","released_while_active","resolved","deaths", "seven_day_moving_total_active_cases","new_cases_Ep_old", 'seven_day_moving_total_new_cases_Ep_old', "new_cases_Ep", 'seven_day_moving_total_new_cases_Ep', "new_cases_Col", 'seven_day_moving_total_new_cases_Col'] ]=  np.nan
ebmud_cases["utility"]="C"
ebmud_cases["sample_code"]=np.nan
ebmud_cases.loc[ebmud_cases.interceptor=="ADA", "sample_code"]='C_C_ADA'
ebmud_cases.loc[ebmud_cases.interceptor=="S68", "sample_code" ]='C_C_S68'
ebmud_cases.loc[ebmud_cases.interceptor=="N49", "sample_code"]='C_C_N49'

#merge
cases= pd.concat([cc_cases,ebmud_cases,sq_cases])
cases['fraction_positive']=np.float64(cases.new_cases)/cases.total_tests
cases=cases.drop("population", axis=1)
cases=cases.drop("fraction_positive", axis=1)

cases.to_csv('/Users/owner/Desktop/case_data_compiled.csv', index=False)

# %%
#santa Clara -- full county not from public health dept
# path='/Users/owner/Desktop/Berkeley_Work/data_analysis/casedata/COVID_CA_data_Santa_Clara.csv'
# sc_cases=pd.read_csv(path)
# sc_cases.date_sampling=pd.to_datetime(sc_cases.date_sampling)
# sc_cases.new_cases=pd.to_numeric(sc_cases.new_cases) #low med high sub in for <11
# sc_cases[["active_cases","total_tests","released_while_active","resolved","deaths", "seven_day_moving_total_active_cases"]]=  np.nan

# #San Jose (75-80% of the population falls in this sewershed which is 1.4 million residents)
# # https://data.sccgov.org/COVID-19/COVID-19-case-counts-by-date/6cnm-gchg 
# # DATE IS THE SPECIMAN COLLECTION DATE
# sj_cases=sc_cases
# sj_cases.new_cases=round(sj_cases.new_cases * 0.75)
# sj_cases.loc[sj_cases.new_cases <1, "new_cases"]=1
# sj_cases["interceptor"]="INF"
# sj_cases["utility"]="E"
# sj_cases["sample_code"]='E_E_INF'
# #Seven day mocing totals
# sj_cases=sj_cases.loc[(sj_cases.date_sampling > e_start)& (sj_cases.date_sampling < e_end),]
# sj_cases=sj_cases.set_index("date_sampling")
# sj_cases=sj_cases.sort_index()
# sj_cases['seven_day_moving_total_new_cases']=sj_cases.rolling(window=7, axis=1)['new_cases'].sum()
# sj_cases=sj_cases.reset_index()

#longformat
cases_long=cases.rename(columns = {'fraction_positive': 'value-fraction_positive', 'new_cases': 'value-new_cases', 'total_tests': 'value-total_tests', 'active_cases': 'value-active_cases',  'released_while_active': 'value-released_while_active', 'active_cases': 'value-active_cases',  'resolved': 'value-resolved',  'deaths': 'value-deaths',  'deaths': 'value-deaths', 'fraction_positive': 'value-fraction_positive'}, inplace = False)
cases_long=pd.wide_to_long(cases_long, stubnames="value", i=["date_sampling","utility","interceptor","sample_code"], j="Target", sep='-', suffix='\w+').reset_index()
cases_long.value = pd.to_numeric(cases_long.value, errors='coerce')
cases_long["processing_error"]="not applicable"
cases_long["replicate"]="not applicable"
cases_long["Storage_conditions"]="not applicable"
cases_long["data_type"]="case data"

#load chem data
chem_data_wide= read_gsheet(gc, samples_url, chem_data)
chem_data_wide['date'] = pd.to_datetime(chem_data_wide['date'], format = '%m/%d/%Y')
chem_data_wide.TSS_mgL = pd.to_numeric(chem_data_wide.TSS_mgL, errors='coerce')
chem_data_wide.COD_mgL = pd.to_numeric(chem_data_wide.COD_mgL, errors='coerce')
chem_data_wide.BOD_mgL = pd.to_numeric(chem_data_wide.BOD_mgL, errors='coerce')
chem_data_wide.cBOD_mgL = pd.to_numeric(chem_data_wide.cBOD_mgL, errors='coerce')
chem_data_wide.flow_MGD = pd.to_numeric(chem_data_wide.flow_MGD, errors='coerce')
chem_data_wide.NH4_mgL = pd.to_numeric(chem_data_wide.NH4_mgL, errors='coerce') 
chem_data_wide=chem_data_wide.rename(columns = {'date': 'date_sampling'})
chem_data_long= chem_data_wide[["date_sampling","utility","interceptor","flow_MGD","TSS_mgL","COD_mgL", "cBOD_mgL","NH4_mgL"]].melt(id_vars= ["date_sampling", "utility", "interceptor"], var_name= "Target" )
chem_data_long.value = pd.to_numeric(chem_data_long.value, errors='coerce')
chem_data_long["processing_error"]="not applicable"
chem_data_long["Storage_conditions"]="not applicable"
chem_data_long["replicate"]="not applicable"
chem_data_long["data_type"]="chem data"

# merge case data & chem data with qpcr_averaged_merged
qpcr_averaged_merged= qpcr_averaged_merged.merge(cases, how='outer', on=["date_sampling","utility","interceptor", "sample_code"])
qpcr_averaged_merged= qpcr_averaged_merged.merge(chem_data_wide, how='outer', on=["date_sampling","utility","interceptor"])
blod_N1_samps=qpcr_averaged_merged.loc[(qpcr_averaged_merged.Target=="N1")&(qpcr_averaged_merged.blod_master_curve==True),"Sample"]
qpcr_averaged_merged_wide= qpcr_averaged_merged.pivot(index=['Sample',"date_sampling","sample_code","utility","interceptor","population","replicate","flow_MGD","TSS_mgL","BOD_mgL","cBOD_mgL","COD_mgL","NH4_mgL", "total_tests","fraction_positive","new_cases","active_cases","released_while_active","resolved","deaths", "seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases"], columns='Target', values='gc_per_L').reset_index()

#long version with more targets to include case data and chem data
qpcr_averaged_merged_long=qpcr_averaged_merged.rename(columns = {'gc_per_L': 'value'})
qpcr_averaged_merged_long=qpcr_averaged_merged_long[["date_sampling","interceptor","utility","replicate","processing_error","Storage_conditions","Target","value"]].copy()
qpcr_averaged_merged_long["data_type"]="qpcr data"
qpcr_averaged_merged_long=qpcr_averaged_merged_long.append(chem_data_long).reset_index()
qpcr_averaged_merged_long=qpcr_averaged_merged_long.append(cases_long).reset_index()
qpcr_averaged_merged_long['date_sampling'] = pd.to_datetime(qpcr_averaged_merged_long['date_sampling'])
qpcr_averaged_merged_long=qpcr_averaged_merged_long.drop(["level_0","index"], axis=1)

# %%
# Loading control full analysis

# r=['2','3']
# i=["INF","SQ","S68","ADA","N49"]
# wfsc_norm=qpcr_averaged_merged_wide[~((qpcr_averaged_merged_wide.utility=="K") & (qpcr_averaged_merged_wide.replicate.isin(r))) ].copy()
# wfsc_norm=qpcr_averaged_merged_wide[~((wfsc_norm.utility=="E") & (wfsc_norm.replicate.isin(r))) ].copy()
# wfsc_norm=wfsc_norm[wfsc_norm.interceptor.isin(i)].copy()
wfsc_norm=qpcr_averaged_merged_wide.copy()

#set a column with the median of each fcc for each interceptor
wfsc_norm['PMMoV_med'] = wfsc_norm.groupby(['utility','interceptor'])["PMMoV"].transform('median')
wfsc_norm['crAss_med'] = wfsc_norm.groupby(['utility','interceptor'])["crAss"].transform('median')
wfsc_norm['18S_med'] = wfsc_norm.groupby(['utility','interceptor'])["18S"].transform('median')
wfsc_norm['bact_med'] = wfsc_norm.groupby(['utility','interceptor'])["bact"].transform('median')

#find the medians of each fcc without considering controls
# m= wfsc_norm[~wfsc_norm.Sample.str.contains("control")]
# wfsc_groupby= m.groupby(["utility", "interceptor"]).agg(PMMoV_med= ('PMMoV', 'median'), crAss_med= ('crAss', 'median'), med_18S= ('18S', 'median'), bact_med= ('bact', 'median')).reset_index()

# #normalize N1 by each loading control / median for that loading control for that interceptor 
wfsc_norm["N1_18S"] =wfsc_norm["N1"]/(wfsc_norm["18S"]/wfsc_norm["18S_med"]) #same units as N1
# #replace the fcc measurement with the median for that assay (so the ratio becomes 1) if N1 is undetermined(set to the LoD) so that they all have a consistent value
wfsc_norm.loc[(wfsc_norm.Sample.isin(blod_N1_samps)) & (~np.isnan(wfsc_norm["18S"])), "N1_18S" ]= wfsc_norm.N1/1

wfsc_norm["N1_bact"] =wfsc_norm["N1"]/(wfsc_norm["bact"]/wfsc_norm["bact_med"])
wfsc_norm.loc[(wfsc_norm.Sample.isin(blod_N1_samps)) & (~np.isnan(wfsc_norm.bact)), "N1_bact" ]= wfsc_norm.N1/1

wfsc_norm["N1_PMMoV"] =wfsc_norm["N1"]/(wfsc_norm["PMMoV"]/wfsc_norm["PMMoV_med"])
wfsc_norm.loc[(wfsc_norm.Sample.isin(blod_N1_samps)) & (~np.isnan(wfsc_norm.PMMoV)), "N1_PMMoV" ]= wfsc_norm.N1/1

wfsc_norm["N1_crAss"] =wfsc_norm["N1"]/(wfsc_norm["crAss"]/wfsc_norm["crAss_med"])
wfsc_norm.loc[(wfsc_norm.Sample.isin(blod_N1_samps)) & (~np.isnan(wfsc_norm.crAss)), "N1_crAss"]= wfsc_norm.N1/1

wfsc_norm["N1_flow"]= wfsc_norm["N1"]*wfsc_norm["flow_MGD"]/pd.to_numeric(wfsc_norm["population"]) #units end up as copies/day/person
wfsc_norm["N1_TSS"] =wfsc_norm["N1"]/wfsc_norm["TSS_mgL"]
wfsc_norm["N1_cBOD"] = wfsc_norm["N1"]/wfsc_norm["cBOD_mgL"]
wfsc_norm["N1_NH4"]= wfsc_norm["N1"]/wfsc_norm["NH4_mgL"]
wfsc_norm["N1_COD"]= wfsc_norm["N1"]/wfsc_norm["COD_mgL"]

wfsc_norm_long= wfsc_norm.melt(id_vars= ["date_sampling", "utility", "interceptor", "population"], 
                               value_vars= ["N1", "N1_PMMoV", "N1_18S", "N1_bact", "N1_crAss", "N1_TSS", "N1_cBOD", "N1_COD","N1_flow"], #,"total_tests","fraction_positive","new_cases","active_cases","released_while_active","resolved","deaths", "seven_day_moving_total_new_cases",  "seven_day_moving_total_active_cases"], 
                               var_name= "Target" )

wfsc_norm_long.value = pd.to_numeric(wfsc_norm_long.value, errors='coerce')
wfsc_norm_long = wfsc_norm_long.dropna()

qpcr_averaged_merged_long['normalized']="N"
wfsc_norm_long["normalized"]="Y"

qpcr_averaged_merged_long=qpcr_averaged_merged_long.append(wfsc_norm_long)

# %%
# interpolation and time series datasets
cols_wfsc= ["N1","N1_crAss","new_cases","seven_day_moving_total_new_cases","seven_day_moving_total_active_cases",  "total_tests", "fraction_positive", "active_cases", "population"]
cols_fill= ["seven_day_moving_total_new_cases","seven_day_moving_total_active_cases",  "total_tests", "fraction_positive", "active_cases", "population"]
cols=["N1_int", "N1C_int"]
cols_fcc=["N1_int", "N1C_int", "N1b_int", "N1P_int", "N1S_int"]
id_list=["K_K_INF", 'E_E_INF', 'B_B_SQ', 'C_C_S68', 'C_C_N49', 'C_C_ADA' ]
g_id=["K_K_INF", 'E_E_INF' ]
gb_list=["date_sampling","utility","interceptor", "sample_code" ]


wfsc_norm_int=wfsc_norm.loc[~pd.isnull(wfsc_norm.sample_code)].copy()
wfsc_norm_int=wfsc_norm_int.loc[wfsc_norm.sample_code.isin(id_list)].copy()
wfsc_norm_int=wfsc_norm_int.dropna(how="all", subset=cols_wfsc) #drop if they all are NA

# drop=["E_Inf_060220_2", "E_Inf_062820_2", "E_Inf_071220_3","E_Inf_080420_3","E_Inf_081120_2"] #visual outliers
# drop=["E_Inf_060420_1", "E_Inf_071920_1", "E_Inf_072820_1", "E_Inf_080420_1"] #based on 18S
# wfsc_norm_int=wfsc_norm_int[~wfsc_norm_int.Sample.isin(drop)].copy()
# reps=["2","3"]
# wfsc_norm_int=wfsc_norm_int[~((wfsc_norm_int.utility=="E") &(wfsc_norm_int.replicate.isin(reps))) ].copy()



# #find which bio triplicates pass grubbs
# test=wfsc_norm_int[["date_sampling","utility","interceptor", "sample_code", "N1"]].copy().dropna()
# test=test[test.sample_code.isin(g_id)].copy()
# test=get_pass_grubbs_test(test,gb_list, col='N1' )


# # #merge that column onnto orig
# # wfsc_norm_int=wfsc_norm_int.merge(test, how='left')
# # wfsc_norm_int=wfsc_norm_int[~(wfsc_norm_int.grubbs_test==False)].copy()
# # wfsc_norm_int=wfsc_norm_int.drop("grubbs_test", axis=1)

wfsc_norm_int.loc[:, cols_fill]=wfsc_norm_int.loc[:, cols_fill].fillna(-1) #to keep during groupby
wfsc_norm_int

qpcr_int=wfsc_norm_int.groupby(["date_sampling","utility","interceptor", "sample_code" ,"new_cases","total_tests", "fraction_positive", "active_cases", "population", "seven_day_moving_total_new_cases","seven_day_moving_total_active_cases" ]).agg(
                                                                          N1_int=("N1", lambda x: sci.gmean(x,axis=0)),
                                                                          N1_gstd=('N1', lambda x: np.nan if ( (len(x.dropna()) <2 )| all(np.isnan(x)) | any(x==0) ) else (sci.gstd(x.dropna(),axis=0))),
                                                                          N1_n= ("N1",'count'),
                                                                          N1C_int=("N1_crAss", lambda x: sci.gmean(x,axis=0)),
                                                                          N1C_gstd=("N1_crAss", lambda x: np.nan if ( (len(x.dropna()) <2 )| all(np.isnan(x)) | any(x==0) ) else (sci.gstd(x.dropna(),axis=0))),
                                                                          NC1_n= ("N1_crAss",'count'),
                                                                          N1P_int=("N1_PMMoV", 'max'),
                                                                          N1P_gstd=("N1_PMMoV", lambda x: np.nan ),
                                                                          N1P_n= ("N1_PMMoV",'count'),
                                                                          N1b_int=("N1_bact", 'max'),
                                                                          N1b_gstd=("N1_bact", lambda x: np.nan ),
                                                                          N1b_n= ("N1_bact",'count'),
                                                                          N1S_int=("N1_18S", 'max'),
                                                                          N1S_gstd=("N1_18S", lambda x: np.nan ),
                                                                          N1S_n= ("N1_18S",'count'),
                                                                          N1_raw= ("N1", list),
                                                                          N1C_raw= ("N1_crAss", list),
                                                                          N1b_raw= ("N1_bact", list),
                                                                          rep= ("replicate", list)
                                                                         ).reset_index()
qpcr_int=qpcr_int.replace(to_replace=-1, value=np.nan) #undo the nan fill with -1


# need to limit each interpolation for N1 andf N1C so it doesn't extendpast the final sample data & general limit
qpcr_int.date_sampling=pd.to_datetime(qpcr_int.date_sampling)
qpcr_int=qpcr_int[(qpcr_int.date_sampling>pd.to_datetime('2020-04-01')) & (qpcr_int.date_sampling<pd.to_datetime('2020-11-01'))].copy()


start_dict={"K_K_INF": pd.to_datetime('2020-06-12'), 'E_E_INF': pd.to_datetime('2020-05-29'),  'B_B_SQ':pd.to_datetime('2020-07-01'), 'C_C_S68':pd.to_datetime('2020-04-21'), 'C_C_N49': pd.to_datetime('2020-04-21'), 'C_C_ADA':pd.to_datetime('2020-05-28')}
end_dict={"K_K_INF": pd.to_datetime('2020-09-04'), 'E_E_INF': pd.to_datetime('2020-09-14'),  'B_B_SQ':pd.to_datetime('2020-09-15'), 'C_C_S68':pd.to_datetime('2020-09-15'), 'C_C_N49': pd.to_datetime('2020-09-15'), 'C_C_ADA':pd.to_datetime('2020-09-09')}
nam_dict={"K_K_INF": "K", 'E_E_INF': "E",  'B_B_SQ':"SQ", 'C_C_S68':"S", 'C_C_N49': "N", 'C_C_ADA':"A"}
pop_dict={"K_K_INF": 483600, 'E_E_INF': 140000,  'C_C_S68':469344, 'C_C_N49': 82818, 'C_C_ADA':139037}
residuals_dict={"K_K_INF": 5, 'E_E_INF': 7,  'B_B_SQ':6, 'C_C_S68':8, 'C_C_N49': 6, 'C_C_ADA':5}
fcc_list=["K_K_INF", "E_E_INF", "B_B_SQ"]

qpcr_long_dict = {}
qpcr_pchip_dict = {}
qpcr_dict = {}
qpcr_loess_dict= {}



for i in id_list:
    qpcr_K= qpcr_int.loc[qpcr_int.sample_code== i,].copy()
    qpcr_K.loc[:,"location"]=nam_dict[i]
    if (i != "B_B_SQ"):
        qpcr_K.loc[:,"population"]=pop_dict[i]
    else:
        qpcr_K['population']=qpcr_K['population'].fillna(method='pad')
    qpcr_K['pop_normalized_cases']=qpcr_K["new_cases"]/pd.to_numeric(qpcr_K['population'])
    qpcr_K_c=qpcr_K.sort_values("date_sampling")

    qpcr_K=qpcr_K.set_index("date_sampling", drop=False)
    qpcr_K_int=qpcr_K.drop("date_sampling", axis=1)
    qpcr_K_int=qpcr_K_int[cols].copy()
    
    #loess
    if i in fcc_list:
        qpcr_K_loess_N1=qpcr_K[cols_fcc].copy().dropna().sort_index()
    else:
        qpcr_K_loess_N1=qpcr_K[cols].copy().dropna().sort_index()

    qpcr_K_loess_N1["Target"]="N1"
    qpcr_K_loess_C=qpcr_K_loess_N1.copy()
    qpcr_K_loess_C["Target"]="N1_crAss"
    qpcr_K_loess_b=qpcr_K_loess_N1.copy()
    qpcr_K_loess_b["Target"]="N1_bact"
    qpcr_K_loess_P=qpcr_K_loess_N1.copy()
    qpcr_K_loess_P["Target"]="N1_PMMoV"
    qpcr_K_loess_S=qpcr_K_loess_N1.copy()
    qpcr_K_loess_S["Target"]="N1_18S"
    value_N1=[]
    value_C=[]
    value_b=[]
    value_P=[]
    value_S=[]

    for j in range(0, len(qpcr_K_loess_N1.N1_int)):
        
        wk=j+1
        wk_str=str(wk)
        wk_str_pred="y_pred_"+wk_str
        qpcr_K_loess_N1[wk_str_pred]=np.nan
        qpcr_K_loess_N1[ wk_str_pred]=make_loess(qpcr_K_loess_N1["N1_int"],wk)
        qpcr_K_loess_N1[wk_str]=qpcr_K_loess_N1["N1_int"]- qpcr_K_loess_N1[wk_str_pred]
        value_N1=value_N1 + [wk_str]
        
        qpcr_K_loess_C[wk_str_pred]=make_loess(qpcr_K_loess_C["N1C_int"],wk)
        qpcr_K_loess_C[wk_str]=qpcr_K_loess_C["N1C_int"]- qpcr_K_loess_C[wk_str_pred]
        value_C=value_C + [wk_str]
        
        if i in fcc_list:
            qpcr_K_loess_b[wk_str_pred]=make_loess(qpcr_K_loess_b["N1b_int"],wk)
            qpcr_K_loess_b[wk_str]=qpcr_K_loess_b["N1b_int"]- qpcr_K_loess_b[wk_str_pred]
            value_b=value_b + [wk_str]
            
            qpcr_K_loess_P[wk_str_pred]=make_loess(qpcr_K_loess_P["N1b_int"],wk)
            qpcr_K_loess_P[wk_str]=qpcr_K_loess_P["N1b_int"]- qpcr_K_loess_P[wk_str_pred]
            value_P=value_P + [wk_str]
            
            qpcr_K_loess_S[wk_str_pred]=make_loess(qpcr_K_loess_S["N1b_int"],wk)
            qpcr_K_loess_S[wk_str]=qpcr_K_loess_S["N1b_int"]- qpcr_K_loess_S[wk_str_pred]
            value_S=value_S + [wk_str]

    qpcr_K_loess_C=qpcr_K_loess_C.reset_index()
    qpcr_K_loess_C1=qpcr_K_loess_C.melt(id_vars= ["date_sampling", "Target"], 
                                   value_vars= value_C,
                                   var_name= "points", 
                                   value_name="residuals")
    qpcr_K_loess_C2=qpcr_K_loess_C.melt(id_vars= ["date_sampling", "Target"], 
                                   value_vars= ["y_pred_" + s for s in value_C],
                                   var_name= "points", 
                                   value_name="y_pred")
    qpcr_K_loess_C2['points']=qpcr_K_loess_C2['points'].apply(lambda x: x.replace("y_pred_",""))
    qpcr_K_loess_C= qpcr_K_loess_C1.merge(qpcr_K_loess_C2)

    qpcr_K_loess_N1=qpcr_K_loess_N1.reset_index()
    qpcr_K_loess_N11=qpcr_K_loess_N1.melt(id_vars= ["date_sampling", "Target"], 
                                   value_vars= value_C,
                                   var_name= "points", 
                                   value_name="residuals")
    qpcr_K_loess_N12=qpcr_K_loess_N1.melt(id_vars= ["date_sampling", "Target"], 
                                   value_vars= ["y_pred_" + s for s in value_C],
                                   var_name= "points", 
                                   value_name="y_pred")
    qpcr_K_loess_N12['points']=qpcr_K_loess_N12['points'].apply(lambda x: x.replace("y_pred_",""))
    qpcr_K_loess_N1= qpcr_K_loess_N11.merge(qpcr_K_loess_N12)
    qpcr_K_loess=qpcr_K_loess_N1.append(qpcr_K_loess_C)

    if i in fcc_list:
            qpcr_K_loess_P=qpcr_K_loess_P.reset_index()
            qpcr_K_loess_P1=qpcr_K_loess_P.melt(id_vars= ["date_sampling", "Target"], 
                                           value_vars= value_C,
                                           var_name= "points", 
                                           value_name="residuals")
            qpcr_K_loess_P2=qpcr_K_loess_P.melt(id_vars= ["date_sampling", "Target"], 
                                           value_vars= ["y_pred_" + s for s in value_C],
                                           var_name= "points", 
                                           value_name="y_pred")
            qpcr_K_loess_P2['points']=qpcr_K_loess_P2['points'].apply(lambda x: x.replace("y_pred_",""))
            qpcr_K_loess_P= qpcr_K_loess_P1.merge(qpcr_K_loess_P2)
            
            qpcr_K_loess_b=qpcr_K_loess_b.reset_index()
            qpcr_K_loess_b1=qpcr_K_loess_b.melt(id_vars= ["date_sampling", "Target"], 
                                           value_vars= value_C,
                                           var_name= "points", 
                                           value_name="residuals")
            qpcr_K_loess_b2=qpcr_K_loess_b.melt(id_vars= ["date_sampling", "Target"], 
                                           value_vars= ["y_pred_" + s for s in value_C],
                                           var_name= "points", 
                                           value_name="y_pred")
            qpcr_K_loess_b2['points']=qpcr_K_loess_b2['points'].apply(lambda x: x.replace("y_pred_",""))
            qpcr_K_loess_b= qpcr_K_loess_b1.merge(qpcr_K_loess_b2)
            
            qpcr_K_loess_S=qpcr_K_loess_S.reset_index()
            qpcr_K_loess_S1=qpcr_K_loess_S.melt(id_vars= ["date_sampling", "Target"], 
                                           value_vars= value_C,
                                           var_name= "points", 
                                           value_name="residuals")
            qpcr_K_loess_S2=qpcr_K_loess_S.melt(id_vars= ["date_sampling", "Target"], 
                                           value_vars= ["y_pred_" + s for s in value_C],
                                           var_name= "points", 
                                           value_name="y_pred")
            qpcr_K_loess_S2['points']=qpcr_K_loess_S2['points'].apply(lambda x: x.replace("y_pred_",""))
            qpcr_K_loess_S= qpcr_K_loess_S1.merge(qpcr_K_loess_S2)
            
            qpcr_K_loess=qpcr_K_loess.append(qpcr_K_loess_P)
            qpcr_K_loess=qpcr_K_loess.append(qpcr_K_loess_b)
            qpcr_K_loess=qpcr_K_loess.append(qpcr_K_loess_S)
    
    #pchip interpolation
    daily=qpcr_K_int.resample('D').interpolate(method='pchip')
    daily.columns=["N1_1D","N1C_1D"]
    daily2=qpcr_K_int.resample('2D').interpolate(method='pchip')
    daily2.columns=["N1_2D","N1C_2D"]
    
    if len(qpcr_K.N1_int.unique()) > 6:
        daily3=qpcr_K_int.resample('3D').interpolate(method='pchip')
        daily3.columns=["N1_3D","N1C_3D"]
        weekly=qpcr_K_int.resample('W').interpolate(method='pchip')
        weekly.columns=["N1_7D","N1C_7D"]
        
    qpcr_K_int=qpcr_K_int.append(daily)
    qpcr_K_int=qpcr_K_int.append(daily2)
    qpcr_K_int=qpcr_K_int.append(daily3)
    qpcr_K_int=qpcr_K_int.append(weekly).reset_index()
    
    Kd=end_dict[i]
    qpcr_K_int= qpcr_K_int.loc[qpcr_K_int.date_sampling<Kd, ]
    qpcr_K_int1= qpcr_K_int.melt(id_vars= ["date_sampling"], 
                                   value_vars= ["N1_1D","N1_2D","N1_3D","N1_7D", "N1C_1D","N1C_2D","N1C_3D","N1C_7D"], 
                                   var_name= "Target" )
    qpcr_K_int2= qpcr_K_c[["date_sampling", "N1_int", "N1C_int",'pop_normalized_cases', "N1_gstd","N1C_gstd"]].copy()
    qpcr_K_int=qpcr_K_int1.merge(qpcr_K_int2, how='left', on= ["date_sampling"])
                            
    
    
    
  
    #no interpolation
    Kd=end_dict[i]
    qpcr_K.loc[qpcr_K.date_sampling>Kd, "N1_int"]=np.nan
    qpcr_K.loc[qpcr_K.date_sampling>Kd, "N1C_int"]=np.nan
    qpcr_K['N1_1diff']=np.nan
    qpcr_K['N1_2diff']=np.nan
    qpcr_K['N1C_1diff']=np.nan
    qpcr_K['N1C_2diff']=np.nan
    qpcr_K['cases_1diff']=np.nan
    qpcr_K['cases_2diff']=np.nan
    qpcr_K['casesP_1diff']=np.nan
    qpcr_K['casesP_2diff']=np.nan
    qpcr_K.loc[~np.isnan(qpcr_K.N1_int), 'N1_1diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.N1_int), "N1_int"].diff()
    qpcr_K.loc[~np.isnan(qpcr_K.N1_1diff), 'N1_2diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.N1_1diff), "N1_1diff"].diff()
    qpcr_K.loc[~np.isnan(qpcr_K.N1C_int), 'N1C_1diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.N1C_int), "N1C_int"].diff()
    qpcr_K.loc[~np.isnan(qpcr_K.N1C_1diff), 'N1C_2diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.N1C_1diff), "N1C_1diff"].diff()
    qpcr_K.loc[~np.isnan(qpcr_K.new_cases), 'cases_1diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.new_cases), "new_cases"].diff()
    qpcr_K.loc[~np.isnan(qpcr_K.cases_1diff), 'cases_2diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.cases_1diff), "cases_1diff"].diff()
    qpcr_K.loc[~np.isnan(qpcr_K.new_cases), 'casesP_1diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.pop_normalized_cases), "pop_normalized_cases"].diff()
    qpcr_K.loc[~np.isnan(qpcr_K.cases_1diff), 'casesP_2diff' ]= qpcr_K.loc[~np.isnan(qpcr_K.casesP_1diff), "casesP_1diff"].diff()
    
#     qpcr_K_long3= qpcr_K.melt(id_vars= ["date_sampling","location"], 
#                                    value_vars= ["loess_N1", "loess_N1C" ], 
#                                    var_name= "loess_target",
#                                    value_name= "loess")
    qpcr_K_long2=qpcr_K[["date_sampling", "N1_gstd","N1C_gstd"]].copy()
    qpcr_K_long2.columns=["date_sampling", "N1_int","N1C_int"]
    qpcr_K_long2= qpcr_K_long2.melt(id_vars= ["date_sampling"], 
                                   value_vars= ["N1_int", "N1C_int" ], 
                                   var_name= "Target",
                                   value_name="gstd"
                             )
    
    qpcr_K_long1= qpcr_K.melt(id_vars= ["date_sampling","location"], 
                                   value_vars= ["N1_int", "N1C_int",'pop_normalized_cases', "total_tests","new_cases","fraction_positive","active_cases" ], 
                                   var_name= "Target" )
    qpcr_K_long= qpcr_K_long1.merge(qpcr_K_long2, how="left")
#     qpcr_K_long= qpcr_K_long.merge(qpcr_K_long3, how="left")
    
    qpcr_long_dict[i] = qpcr_K_long
    qpcr_dict[i]=qpcr_K 
    qpcr_pchip_dict[i]=qpcr_K_int
    qpcr_loess_dict[i]=qpcr_K_loess

# %%
# qpcr_int.loc[(qpcr_int.sample_code=="E_E_INF")&(~np.isnan(qpcr_int.N1_int)), :]
len(qpcr_int.N1_int)

# wfsc_norm_int[(~np.isnan(wfsc_norm_int.N1))&(wfsc_norm_int.sample_code=="K_K_INF")][["N1","PMMoV","N1_PMMoV"]]
# qpcr_int[(~np.isnan(qpcr_int.N1_int))&(qpcr_int.sample_code=="K_K_INF")][["date_sampling", "N1_int", "N1_int", "N1b_raw"]]
# Out:
# 1104

# %%
# qpcr_["K_K_INF"][["date_sampling","N1_int", "loess_N1"]]
# qpcr_long_dict["K_K_INF"].loess.unique()

# %% [markdown]
# ### Extra checks for missing samples

# %%
x="C_N49_072120_1" 
# qpcr_raw[qpcr_raw.Sample==x]
# qpcr_processed[qpcr_processed.Sample==x][["Sample", "Target", "dilution", "is_dilution","raw_Cq_values","sub_Cq_values", "outlier_Cq_values", "Cq_mean","Quantity_mean","plate_id"]]
# sample_data[sample_data.sample_id==x][["weight_vol_extracted_ml", "elution_vol_ul"]]
# qpcr_averaged_merged[qpcr_averaged_merged.Sample==x][["Sample", "Target", "dilution", "is_dilution","raw_Cq_values","sub_Cq_values", "outlier_Cq_values", "Cq_mean","Quantity_mean", "gc_per_L"]]
# qpcr_averaged_merged_wide[qpcr_averaged_merged_wide.Sample==x][["Sample","N1","crAss"]]

# wfsc_norm[(wfsc_norm.interceptor=="N49")& (wfsc_norm.date_sampling==pd.to_datetime("2020-07-21"))][["Sample","N1","crAss", "N1_crAss"]]
# qpcr_int[(qpcr_int.interceptor=="N49")& (qpcr_int.date_sampling==pd.to_datetime("2020-07-21"))][["N1_int", "N1C_int"]]
# a=qpcr_long_dict["C_C_N49"]
# a[a.date_sampling=="2020-07-21"]


# wfsc_norm[(wfsc_norm.utility=="K")& (wfsc_norm.date_sampling==pd.to_datetime("2020-08-07"))][["Sample","N1","crAss", "N1_crAss"]]
# qpcr_int[(qpcr_int.utility=="K")& (qpcr_int.date_sampling=="2020-08-07")][["N1_int", "N1C_int"]]
# a=qpcr_long_dict["K_K_INF"]
# a[a.date_sampling=="2020-08-07"]

# %%
#make sample data better to produce tables
sample_data["processed"]=0
sample_data.loc[sample_data.date_extract != "","processed"]=1
sample_data["N1_qpcr"]=0
uni=qpcr_averaged[(qpcr_averaged.Target == 'N1')].Sample.unique()
sample_data.loc[sample_data.sample_id.isin(uni) ,"N1_qpcr"]=1
sample_data["paper"]=0
num=['B01','B02','B03','B04','B05','B06','B07','B08','B09','B10','B11','B12','B13','B14','B15','B19']
sample_data.loc[sample_data.batch.isin(num),"paper"]=1
sample_data["sub_id"]=sample_data['sample_id'].str.slice(0, -2)

sample_data_80=sample_data[sample_data.stored_minus_80=='1'].copy()
sample_data=sample_data[sample_data.processed_fresh != '']
sample_data.processed_fresh=sample_data.processed_fresh.astype('int')
sample_data_fresh=sample_data[sample_data.processed_fresh==1].copy()
sample_data_u=sample_data_80[['facility',"interceptor",'date_sampling','date_extract','processed',"N1_qpcr","paper"]].drop_duplicates()
sample_data_fresh_u=sample_data_fresh[['facility',"interceptor",'date_sampling','date_extract','processed',"N1_qpcr","paper"]].drop_duplicates()
sample_data=sample_data[(sample_data.processed_fresh != 1)&(~np.isnan(sample_data.processed_fresh))].copy()
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Std curve Assessment

# %%
# s_plates=[109, 97, 110, 102] #these are the plates with long std curves
std_curve_df[std_curve_df.plate_id.isin(plates)]
# Out:
#     plate_id Target  num_points  Cq_of_lowest_std_quantity  \
# 0         68  PMMoV           7                   3.60E+01
# 1         85     N1           7                   3.79E+01
# 3         86     N1           7                   3.72E+01
# 5         87     N1           6                   3.71E+01
# 7         88     N1           7                   3.70E+01
# 9         91     N1           7                   3.82E+01
# 11        92     N1           7                   3.74E+01
# 13        93     N1           7                   3.84E+01
# 15        94     N1           7                   3.84E+01
# 17        95     N1           7                   3.61E+01
# 19        96     N1           7                   3.71E+01
# 21        99     N1           7                   3.70E+01
# 23       100     N1           7                   3.68E+01
# 25       101     N1           7                   3.84E+01
# 27       102     N1           7                   3.63E+01
# ...

# %% [markdown]
# # Time Series plots

# %% [markdown]
# ## Controls

# %% [markdown]
# ### PBS & Samples

# %%
a=qpcr_averaged
a.loc[a.Quantity_mean<0.000000001, "Quantity_mean"]=0.1
a.loc[a.Sample.str.contains("control"),"Task"]="PBS control"
# a=a[a.interceptor =="PBS"]
a=a[a.Target!="N1"]
b=["B01","B07","B18"]
a=a[a.batch.isin(b)]
a[(a.batch=="B01")&(a.Target=="crAss")]

plt = (ggplot(a, aes(x='batch', y='Quantity_mean', color = "Task")) + 
geom_boxplot()+
# geom_point()+
scale_y_log10(expand=(.1,0))+
facet_wrap('~Target', ncol=2, scales='free_y')+ #, 
geom_hline(yintercept=0.12)+
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(8,8)) )

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/facets/facet.py:552: PlotnineWarning:
#
# If you need more space for the x-axis tick text use ... + theme(subplots_adjust={'wspace': 0.25}). Choose an appropriate value for 'wspace'.
# <ggplot: (275616993)>

# %% [markdown]
# ### NTCs & PBS

# %%
control_df.loc[control_df.Quantity_mean<0.000000001, "Quantity_mean"]=0.1

a=control_df
b=control_df

a=a[a.Target!="Xeno"].copy()
b=b[b.Target!="Xeno"].copy()
hb=0.01
hP=0.01
a['height']=np.nan
a.loc[a.Task=='Negative Control','height']=hb
a.loc[a.Task=='PBS control','height']=hP


#get biological triplicate inf
a= a.groupby(["Target","Task"]).agg(height=('height','min'),  n=('Quantity_mean','count')).reset_index()

#get n=label                                                                   
a['n']='n= '+a['n'].astype('str')

a

plt = (ggplot(b, aes(x='Target', y='Quantity_mean', color = "Task")) + 
geom_boxplot()+
geom_point()+
# ylab('')+
# xlab("")+
scale_y_log10(expand=(.1,0))+
# geom_text(a, aes(x = 'Target', y = 'height',label='n'),ha='center', va='center')+
facet_wrap('~Task', nrow=2, scales='free_y')+ #, 
geom_hline(yintercept=0.12)+
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(8,8)) )

plt
# Out:
# <ggplot: (329798471)>

# %% [markdown]
# # all

# %%
i=["INF","SQ"]
a=qpcr_averaged_merged[qpcr_averaged_merged.interceptor.isin(i)]

a.groupby(["utility","interceptor","batch","Target"]).agg(n=('date_sampling','count'),  avg_undetermined=('is_undetermined_count','mean'),median_undetermined=('is_undetermined_count','median'), total_undetermined=('is_undetermined_count','sum'))
# Out:
#                                    n  avg_undetermined  median_undetermined  \
# utility interceptor batch Target
# B       INF         B07   N1       1          0.00E+00             0.00E+00
#         SQ          B07   18S      9          0.00E+00             0.00E+00
#                           GFP      4          0.00E+00             0.00E+00
#                           N1       9          7.78E-01             0.00E+00
#                           PMMoV    9          0.00E+00             0.00E+00
#                           bCoV     4          0.00E+00             0.00E+00
#                           bact     9          0.00E+00             0.00E+00
#                           crAss    9          0.00E+00             0.00E+00
#                     B18   18S      2          0.00E+00             0.00E+00
#                           N1       2          1.50E+00             1.50E+00
#                           PMMoV    2          0.00E+00             0.00E+00
# ...

# %% [markdown]
# ### Stats

# %%
#right now subbing in 0 as  bdl values
#following this https://towardsdatascience.com/granger-causality-and-vector-auto-regressive-model-for-time-series-forecasting-3226a64889a6

a=qpcr_int[["N1_int", "N1C_int", "date_sampling", "new_cases"]]
wastewater_unnormalized=a["N1_int"].dropna()

mplt.figure(figsize=(14,6))
mplt.subplot(1,2,1)
wastewater_unnormalized.hist(bins=50)
mplt.subplot(1,2,2)
sci.probplot(wastewater_unnormalized, plot=mplt);
wastewater_unnormalized.describe().T
# Out:
# count   9.10E+01
# mean    9.78E+04
# std     5.35E+05
# min     2.00E+03
# 25%     2.00E+03
# 50%     1.30E+04
# 75%     2.80E+04
# max     4.89E+06
# Name: N1_int, dtype: float64

# %%
#right now subbing in 0 as  bdl values
#following this https://towardsdatascience.com/granger-causality-and-vector-auto-regressive-model-for-time-series-forecasting-3226a64889a6

a=qpcr_int[["N1_int", "N1C_int", "date_sampling", "new_cases"]]
a=a[a.N1_int >0.1]
log_ww_unnormalized=np.log10(a.N1_int)

mplt.figure(figsize=(14,6))
mplt.subplot(1,2,1)
log_ww_unnormalized.hist()
mplt.subplot(1,2,2)
sci.probplot(log_ww_unnormalized, plot=mplt);
log_ww_unnormalized.describe().T
# Out:
# count   9.10E+01
# mean    4.07E+00
# std     6.72E-01
# min     3.30E+00
# 25%     3.30E+00
# 50%     4.12E+00
# 75%     4.45E+00
# max     6.69E+00
# Name: N1_int, dtype: float64

# %% [markdown]
# ## Number of unique dates to expect for each interceptor & naming conventions

# %%
#unique number of dates to expect for each interceptor
pK=13
pE=19
pSQ=10
pS=20
pA=11
pN=18

lw=1

name_N1C_int= "N1 normalized to median normalized crAss\nwhere model is lowess alpha= {}\n"
name_N1_int="N1 gc/mL\nwhere model is lowess alpha= {}\n"
name_new_cases="new cases per day unnormalized\nwhere model is seven day moving average\n"
name_active_cases="active cases per day unnormalized\nwhere model is seven day moving average\n"

# %% [markdown]
# ### Contra Costa

# %% [markdown]
# #### Old plots

# %% [markdown]
# ##### Orig data exploration

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="N"]
# a=a[a.interceptor !="PBS"]
# a=a[a.utility=='K']
# # a=a[a.data_type!="chem data"]
# a=a[a.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]

# no=["active_cases","population","seven_day_moving_total_new_cases","released_while_active","resolved","deaths","GFP","bCoV"]
# a=a[~a.Target.isin(no)].copy() #not there


# category_order=["N1","bact","18S","crAss","PMMoV","flow_MGD","TSS_mgL","cBOD_mgL","COD_mgL","NH4_mgL", "new_cases","total_tests","fraction_positive"]
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)


# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# geom_smooth(method='loess')+
# # geom_line()+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=5, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15, 10)) )

# plt

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="Y"]
# a=a[a.interceptor !="PBS"]
# a=a[a.utility=='K']
# a=a[a.data_type!="chem data"]

# # no=["active_cases","population","seven_day_moving_total_new_cases","released_while_active","resolved","deaths","GFP","bCoV", "N1_COD"]
# no=["active_cases","population","seven_day_moving_total_new_cases","released_while_active","resolved","deaths","GFP","bCoV", "N1_COD","N1_bact","N1_18S","N1_PMMoV","N1_flow","N1_TSS","N1_cBOD"]
# a=a[~a.Target.isin(no)].copy() #not there

# # category_order=["N1","N1_bact","N1_18S","N1_crAss","N1_PMMoV","N1_flow","N1_TSS","N1_cBOD", "new_cases","total_tests","fraction_positive"]
# category_order=["N1","N1_crAss", "new_cases","total_tests","fraction_positive"]
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)


# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# # geom_smooth(method='loess')+
# geom_line()+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 15)) )

# plt

# %% [markdown]
# ##### Smoothing using different spans for geom_smooth

# %%
# a=qpcr_long_dict["E_E_INF"]
# a=a[~np.isnan(a.value)]

# # colors
# cmap = cm.get_cmap('viridis', 8)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int","N1_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# alpha= [0.65, 0.7,0.75,0.8,0.85,0.9,0.95,1]
# a['ymax']=a.value * a.gstd
# a['ymin']=a.value / a.gstd

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# # geom_smooth(method='loess', span= 0.65, se=False) +
# geom_point(a, aes(x='date_sampling', y='value'))+
# geom_hline(yintercept=N1_LoD, linetype='dashed')+
# geom_hline(yintercept=4000, linetype='dashed')+
# geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# ylab('')+
# xlab("")+
# scale_y_log10()+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5, 7)) )



# # #title for the plot
# # n='E_loess_alpha_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # plt.save(path)

# plt

# %% [markdown]
# ##### Smoothing with pchip

# %%
# a=qpcr_pchip_dict["K_K_INF"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1C_')]
# a['ymax']=a["N1_int"] * a["N1_gstd"]
# a['ymin']=a["N1_int"] / a["N1_gstd"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_pointrange(aes(x='date_sampling', y='N1_int', ymax='ymax', ymin='ymin'))+
# # geom_line()+
# ylab('N1 gc/L')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='K_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# a=qpcr_pchip_dict["K_K_INF"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1_')]

# a['ymax']=a["N1C_int"] * a["N1C_gstd"]
# a['ymin']=a["N1C_int"] / a["N1C_gstd"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_pointrange(aes(x='date_sampling', y='N1C_int', ymax='ymax', ymin='ymin'))+
# # geom_line()+
# ylab('N1 normalized to crAss')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='K_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
b=wfsc_norm[["interceptor","utility","N1",'N1_crAss',"new_cases", "date_sampling"]].sort_values('date_sampling').copy()
b=b[b.utility=='K']

b=b[b.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
b=b[b.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]
# b=b[~np.isnan(b.N1)]

# grangercausalitytests(b[['N1', 'new_cases']], maxlag=3)
# grangercausalitytests(b[['N1_crAss', 'new_cases']], maxlag=3)

# %% [markdown]
# #### Granger test

# %% [markdown]
# ##### Stationarity and autocorrelation

# %%
test=qpcr_dict["K_K_INF"].reset_index(drop=True)
test=test[~np.isnan(test.N1_int)]
test_col=test[["N1_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -3.648989
# p-value: 0.004891
# Critical Values:
# 	1%: -4.332
# 	5%: -3.233
# 	10%: -2.749
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (330078384)>

# %%
test=qpcr_dict["K_K_INF"].reset_index(drop=True)
test=test[~np.isnan(test.N1C_int)]
test_col=test[["N1C_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1C_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1C_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -3.680380
# p-value: 0.004398
# Critical Values:
# 	1%: -4.939
# 	5%: -3.478
# 	10%: -2.844
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036524632383)>

# %%
test=qpcr_dict["K_K_INF"].reset_index(drop=True)
test=test[~np.isnan(test.new_cases)]
test_col=test[["cases_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='cases_2diff'))+
geom_point(test, aes(x='date_sampling', y='new_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -11.420207
# p-value: 0.000000
# Critical Values:
# 	1%: -3.469
# 	5%: -2.878
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036524569705)>

# %%
test=qpcr_dict["K_K_INF"].reset_index(drop=True)
test=test[~np.isnan(test.pop_normalized_cases)]
test_col=test[["casesP_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='casesP_2diff'))+
geom_point(test, aes(x='date_sampling', y='pop_normalized_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -11.420207
# p-value: 0.000000
# Critical Values:
# 	1%: -3.469
# 	5%: -2.878
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (330272369)>

# %% [markdown]
# ##### stat test

# %%
#can only run this with a start of at least 10 (thus 8 pts after differencing)
b=qpcr_dict["K_K_INF"].reset_index(drop=True)[["N1_2diff",'cases_2diff', "date_sampling"]].sort_values('date_sampling').copy()
b=b.dropna()

c=qpcr_dict["K_K_INF"].reset_index(drop=True)[["N1C_2diff",'casesP_2diff', "date_sampling"]].sort_values('date_sampling').copy()
c=c.dropna()

# grangercausalitytests(b[["N1_2diff",'cases_2diff']], maxlag=2)
# grangercausalitytests(b[["N1_2diff", 'casesP_2diff',]], maxlag=2)

# %% [markdown]
# #### Smoothing with loess

# %%
code="K_K_INF"
a=qpcr_loess_dict[code]

a.points=pd.to_numeric(a.points)
a['alpha_v']=a.points/(pK-1)
a['alpha_rounded']=a.alpha_v.apply(lambda x: round(x,2) ).astype(object)

plt = (ggplot(a, aes(x='date_sampling', y='residuals')) + 
    geom_point()+
    ylab("K_K_INF loess residuals")+
    geom_smooth(method='loess', span= 1, se=False)+
    facet_grid('Target~points +alpha_rounded ', scales='free_y')+
    xlab("")+
    theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15,5)) )
    
#choosing 5 for N1 and crass
pts=5
alpha=pd.to_numeric(a.loc[a.points==pts, "alpha_v"].unique().item())

plt
# Out:
# <ggplot: (-9223372036524451959)>

# %%
loess=qpcr_loess_dict[code].copy()

loess_N1=loess[loess.Target=="N1"].copy()
loess_N1["Target"]="N1_int"
loess_N1_int= loess_N1.loc[loess_N1.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1_int=loess_N1_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1_int["y_pred_int"]=loess_N1_int["y_pred"].interpolate(method='linear')


loess_N1C=loess[loess.Target=="N1_crAss"].copy()
loess_N1C["Target"]="N1C_int"
loess_N1C_int= loess_N1C.loc[loess_N1C.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1C_int=loess_N1C_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1C_int["y_pred_int"]=loess_N1C_int["y_pred"].interpolate(method='linear')

loess_N1=loess_N1.reset_index(drop=True)
loess_N1C=loess_N1C.reset_index(drop=True)

pt=loess_N1.alpha_v.unique()


#merge lowess and case data models to create a dataframe of models
case_model_lookup=qpcr_int[qpcr_int.sample_code==code][["date_sampling","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases"]].copy()
models_merge= loess_N1C_int.copy().reset_index().drop("y_pred",axis=1)
models_merge.columns=["date_sampling", "N1C_int"]

models_int=loess_N1_int.reset_index().merge(case_model_lookup, how='left', on='date_sampling')
models_int["mvga_7D_new_cases"]= models_int["seven_day_moving_total_new_cases"]/7
models_int["mvga_7D_active_cases"]= models_int["seven_day_moving_total_active_cases"]/7
models_int=models_int.drop(["y_pred","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases" ], axis=1)
models_int.columns=["date_sampling","N1_int", "new_cases", "active_cases"]
models_int=models_int.merge(models_merge, how='left', on='date_sampling')

models_int_long=models_int.copy().melt(id_vars="date_sampling", value_vars=["N1_int", "new_cases", "active_cases", "N1C_int"], var_name="Target", value_name="model")

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]

b=loess_N1.loc[loess_N1.alpha_v==alpha,].copy()


t=["N1_int"]
a=a[a.Target.isin(t)]
a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_smooth(method='lowess', span= alpha, se=False, size=lw, color='black')+
geom_point(b,aes(x='date_sampling', y='y_pred'), color='red')+
geom_hline(yintercept=N1_LoD, linetype='dashed')+
geom_hline(yintercept=4000, linetype='dashed')+
ylab('')+
xlab("")+
# scale_y_log10()+
facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5,3)) )



plt
# Out:
# <ggplot: (331296085)>

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
b=loess_N1.copy()

t=["N1_int"]
a=a[a.Target.isin(t)]
a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd
# 

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_point(b,aes(x='date_sampling', y='y_pred', color='alpha_rounded'))+
scale_color_cmap_d('viridis')+
geom_hline(yintercept=N1_LoD, linetype='dashed')+
geom_hline(yintercept=4000, linetype='dashed')+
ylab('')+
xlab("")+
# scale_y_log10()+
facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5,3)) )



print(plt)


# colors
cmap = cm.get_cmap('viridis', 12)    # PiYG
colors=[]
for i in range(cmap.N):
    rgba = cmap(i)
    # rgb2hex accepts rgb or rgba
    colors.append(matplotlib.colors.rgb2hex(rgba))


plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
[geom_smooth(method='lowess', span= pt[i], se=False, size=lw, color=colors[i]) for i in range(0,12)] +
geom_hline(yintercept=N1_LoD, linetype='dashed')+
geom_hline(yintercept=4000, linetype='dashed')+
ylab('')+
xlab("")+
# scale_y_log10()+
facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5,3)) )



print(plt)
# Out:
# <ggplot: (331345542)>
# <ggplot: (-9223372036523349844)>

# %% [markdown]
# #### Final Plot

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
a.Target.unique()
a=a[(a.date_sampling >= start_dict[code]) & (a.date_sampling <= end_dict[code])]

a=a.merge(models_int_long, how='left', on=["date_sampling", "Target"])
a.loc[a.Target== "N1_int", "value"]= a.loc[a.Target== "N1_int", "value"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "value"]= a.loc[a.Target== "N1C_int", "value"]/1000 #convert to same om as above ONLY when normalized to the median
a.loc[a.Target== "N1_int", "model"]= a.loc[a.Target== "N1_int", "model"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "model"]= a.loc[a.Target== "N1C_int", "model"]/1000 #convert to same om as above ONLY when normalized to the median

t=["N1C_int","N1_int","new_cases"]
a=a[a.Target.isin(t)]
a["Target_p"]=a.Target
a.loc[a.Target=="N1C_int", "Target"]= name_N1C_int.format(round(alpha,2))
a.loc[a.Target=="N1_int", "Target"]= name_N1_int.format(round(alpha,2))
a.loc[a.Target=="new_cases", "Target"]= name_new_cases


a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

hlinedf= pd.DataFrame({'Target': [name_N1C_int.format(round(alpha,2)),name_N1_int.format(round(alpha,2)), name_new_cases],
        'h_val': [N1_LoD/1000,N1_LoD/1000,0.999], 'color':['black','black','white']
        }, columns = ['Target', 'h_val', 'color'])

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_line(a, aes(x='date_sampling', y='model', color='Target'), size=lw)+
geom_hline(hlinedf,aes(yintercept='h_val'), linetype='dashed', color=hlinedf.color)+
ylab('')+
xlab("")+
scale_color_cmap_d('viridis')+
scale_y_log10()+
facet_wrap('~Target', ncol=1)+ #, 
theme_classic()+ theme(legend_position='none', strip_text_x = element_text(margin={'t': 15}), axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6, 10)) )



# #title for the plot
# n='K_loess_alpha_var' 
# plot1=n  +'.pdf'
# #path for the plot
# path=os.path.join(dir_test, plot1)
# #save the plot


# plt.save(path)

k=a.copy()
k["location"]="K"


plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_pointrange : Removed 85 rows containing missing values.
# <ggplot: (-9223372036523283561)>

# %%
a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique()
qpcr_int[(qpcr_int.sample_code==code) &(qpcr_int.N1_n>0)][["date_sampling","N1_n","N1_int","N1C_int"]].sort_values("date_sampling")
len(a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique())== pK
# Out:
# True

# %% [markdown]
# ## San Jose

# %% [markdown]
# #### Old plots

# %% [markdown]
# ##### Orig data exploration

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="N"]
# a=a[a.utility=='E']
# a=a[a.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]


# no=["cBOD_mgL","NH4_mgL","active_cases","population","seven_day_moving_total_new_cases","released_while_active","resolved","deaths","GFP","bCoV", "N1_COD","total_tests","fraction_positive"]
# a=a[~a.Target.isin(no)].copy() #not there
# category_order=["N1","bact","18S","crAss","PMMoV","flow_MGD","TSS_mgL","COD_mgL", "new_cases"]#,"total_tests","fraction_positive"]

# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)


# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# geom_smooth(method='loess')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=5, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15, 8)) )

# plt

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="Y"]
# a=a[a.utility=='E']

# a=a[a.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]


# # no=["N1_cBOD","N1_NH4","N1_COD","active_cases","population","seven_day_moving_total_new_cases","released_while_active","resolved","deaths","GFP","bCoV", "N1_COD","total_tests","fraction_positive"]
# no=["N1_cBOD","N1_NH4","N1_COD","active_cases","population","seven_day_moving_total_new_cases","released_while_active","resolved","deaths","GFP","bCoV", "N1_COD","total_tests","fraction_positive", "N1_bact","N1_18S","N1_PMMoV","N1_flow","N1_TSS"]
# a=a[~a.Target.isin(no)].copy() #not there
# a.Target.unique()
# # category_order=["N1","N1_bact","N1_18S","N1_crAss","N1_PMMoV","N1_flow","N1_TSS","new_cases"] #, "new_cases","total_tests","fraction_positive"]
# category_order=["N1","N1_crAss","new_cases"] #, "new_cases","total_tests","fraction_positive"]
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# # geom_smooth(method='loess')+
#        geom_line()+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,9)) )

# plt

# %% [markdown]
# ##### Smoothing using different spans for geom_smooth

# %%
# a=qpcr_long_dict["E_E_INF"]
# a=a[~np.isnan(a.value)]

# # colors
# cmap = cm.get_cmap('viridis', 8)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int","N1_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# alpha= [0.65, 0.7,0.75,0.8,0.85,0.9,0.95,1]
# a['ymax']=a.value * a.gstd
# a['ymin']=a.value / a.gstd

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# # geom_smooth(method='loess', span= 0.65, se=False) +
# geom_point(a, aes(x='date_sampling', y='value'))+
# geom_hline(yintercept=N1_LoD, linetype='dashed')+
# geom_hline(yintercept=4000, linetype='dashed')+
# geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# ylab('')+
# xlab("")+
# scale_y_log10()+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5, 7)) )



# # #title for the plot
# # n='E_loess_alpha_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # plt.save(path)

# plt

# %% [markdown]
# ##### Smoothing with pchip

# %%
# a=qpcr_pchip_dict["E_E_INF"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1C_')]
# a=a[a.Target!= "N1_7D"]
# a['ymax']=a["N1_int"] * a["N1_gstd"]
# a['ymin']=a["N1_int"] / a["N1_gstd"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_pointrange(aes(x='date_sampling', y='N1_int', ymax='ymax', ymin='ymin'))+
# # geom_line()+
# ylab('N1 gc/L')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='E_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# a=qpcr_pchip_dict["E_E_INF"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1_')]
# a=a[a.Target!= "N1C_7D"]

# a['ymax']=a["N1C_int"] * a["N1C_gstd"]
# a['ymin']=a["N1C_int"] / a["N1C_gstd"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_pointrange(aes(x='date_sampling', y='N1C_int', ymax='ymax', ymin='ymin'))+
# # geom_line()+
# ylab('N1 normalized to crAss')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='E_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# b=wfsc_norm[["interceptor","utility","N1",'N1_crAss',"new_cases", "date_sampling"]].sort_values('date_sampling').copy()
# b=b[b.utility=='E']

# b=b[b.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
# b=b[b.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]
# # b=b[~np.isnan(b.N1)]

# # grangercausalitytests(b[['N1', 'new_cases']], maxlag=3)
# # grangercausalitytests(b[['N1_crAss', 'new_cases']], maxlag=3)

# %% [markdown]
# #### Granger test

# %% [markdown]
# ##### Stationarity and autocorrelation

# %%
test=qpcr_dict["E_E_INF"].reset_index(drop=True)
test=test[~np.isnan(test.N1_int)]
test_col=test[["N1_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -5.154547
# p-value: 0.000011
# Critical Values:
# 	1%: -4.012
# 	5%: -3.104
# 	10%: -2.691
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (331635604)>

# %%
test=qpcr_dict["E_E_INF"].reset_index(drop=True)
test=test[~np.isnan(test.N1C_int)]
test_col=test[["N1C_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1C_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1C_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -10.778651
# p-value: 0.000000
# Critical Values:
# 	1%: -3.964
# 	5%: -3.085
# 	10%: -2.682
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036523076138)>

# %%
test=qpcr_dict["E_E_INF"].reset_index(drop=True)
test=test[~np.isnan(test.new_cases)]
test_col=test[["cases_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='cases_2diff'))+
geom_point(test, aes(x='date_sampling', y='new_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -4.807303
# p-value: 0.000053
# Critical Values:
# 	1%: -3.470
# 	5%: -2.879
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (331767416)>

# %%
test=qpcr_dict["E_E_INF"].reset_index(drop=True)
test=test[~np.isnan(test.pop_normalized_cases)]
test_col=test[["casesP_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='casesP_2diff'))+
geom_point(test, aes(x='date_sampling', y='pop_normalized_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -4.807303
# p-value: 0.000053
# Critical Values:
# 	1%: -3.470
# 	5%: -2.879
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036522942604)>

# %% [markdown]
# ##### stat test

# %%
#can only run this with a start of at least 10 (thus 8 pts after differencing)
b=qpcr_dict["E_E_INF"].reset_index(drop=True)[["N1_2diff",'cases_2diff', "date_sampling"]].sort_values('date_sampling').copy()
b=b.dropna()

c=qpcr_dict["E_E_INF"].reset_index(drop=True)[["N1C_2diff",'casesP_2diff', "date_sampling"]].sort_values('date_sampling').copy()
c=c.dropna()

grangercausalitytests(b[["N1_2diff",'cases_2diff']], maxlag=2)
grangercausalitytests(c[["N1C_2diff", 'casesP_2diff',]], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0298  , p=0.8656  , df_denom=13, df_num=1
# ssr based chi2 test:   chi2=0.0367  , p=0.8481  , df=1
# likelihood ratio test: chi2=0.0366  , p=0.8482  , df=1
# parameter F test:         F=0.0298  , p=0.8656  , df_denom=13, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6585  , p=0.5387  , df_denom=10, df_num=2
# ssr based chi2 test:   chi2=1.9754  , p=0.3724  , df=2
# likelihood ratio test: chi2=1.8557  , p=0.3954  , df=2
# parameter F test:         F=0.6585  , p=0.5387  , df_denom=10, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6991  , p=0.1244  , df_denom=13, df_num=1
# ssr based chi2 test:   chi2=3.3220  , p=0.0684  , df=1
# likelihood ratio test: chi2=3.0185  , p=0.0823  , df=1
# parameter F test:         F=2.6991  , p=0.1244  , df_denom=13, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ...

# %% [markdown]
# #### Smoothing with loess

# %%
code="E_E_INF"
a=qpcr_loess_dict[code]

a.points=pd.to_numeric(a.points)
a['alpha_v']=a.points/(pK-1)
a['alpha_rounded']=a.alpha_v.apply(lambda x: round(x,2) ).astype(object)

plt = (ggplot(a, aes(x='date_sampling', y='residuals')) + 
    geom_point()+
    ylab("K_K_INF loess residuals")+
    geom_smooth(method='loess', span= 1, se=False)+
    facet_grid('Target~points +alpha_rounded ', scales='free_y')+
    xlab("")+
    theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15,5)) )
    
#choosing 7 for N1 and crass
pts=7
alpha=pd.to_numeric(a.loc[a.points==pts, "alpha_v"].unique().item())

plt
# Out:
# <ggplot: (-9223372036523472566)>

# %%
loess=qpcr_loess_dict[code].copy()

loess_N1=loess[loess.Target=="N1"].copy()
loess_N1["Target"]="N1_int"
loess_N1_int= loess_N1.loc[loess_N1.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1_int=loess_N1_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1_int["y_pred_int"]=loess_N1_int["y_pred"].interpolate(method='linear')


loess_N1C=loess[loess.Target=="N1_crAss"].copy()
loess_N1C["Target"]="N1C_int"
loess_N1C_int= loess_N1C.loc[loess_N1C.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1C_int=loess_N1C_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1C_int["y_pred_int"]=loess_N1C_int["y_pred"].interpolate(method='linear')

loess_N1=loess_N1.reset_index(drop=True)
loess_N1C=loess_N1C.reset_index(drop=True)

pt=loess_N1.alpha_v.unique()


#merge lowess and case data models to create a dataframe of models
case_model_lookup=qpcr_int[qpcr_int.sample_code==code][["date_sampling","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases"]].copy()
models_merge= loess_N1C_int.copy().reset_index().drop("y_pred",axis=1)
models_merge.columns=["date_sampling", "N1C_int"]

models_int=loess_N1_int.reset_index().merge(case_model_lookup, how='left', on='date_sampling')
models_int["mvga_7D_new_cases"]= models_int["seven_day_moving_total_new_cases"]/7
models_int["mvga_7D_active_cases"]= models_int["seven_day_moving_total_active_cases"]/7
models_int=models_int.drop(["y_pred","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases" ], axis=1)
models_int.columns=["date_sampling","N1_int", "new_cases", "active_cases"]
models_int=models_int.merge(models_merge, how='left', on='date_sampling')

models_int_long=models_int.copy().melt(id_vars="date_sampling", value_vars=["N1_int", "new_cases", "active_cases", "N1C_int"], var_name="Target", value_name="model")

# %% [markdown]
# #### Final Plot

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
a.Target.unique()
a=a[(a.date_sampling >= start_dict[code]) & (a.date_sampling <= end_dict[code])]

a=a.merge(models_int_long, how='left', on=["date_sampling", "Target"])
a.loc[a.Target== "N1_int", "value"]= a.loc[a.Target== "N1_int", "value"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "value"]= a.loc[a.Target== "N1C_int", "value"]/1000 #convert to same om as above ONLY when normalized to the median
a.loc[a.Target== "N1_int", "model"]= a.loc[a.Target== "N1_int", "model"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "model"]= a.loc[a.Target== "N1C_int", "model"]/1000 #convert to same om as above ONLY when normalized to the median

t=["N1C_int","N1_int","new_cases"]
a=a[a.Target.isin(t)]
a.Target_p=a.Target
a.loc[a.Target=="N1C_int", "Target"]= name_N1C_int.format(round(alpha,2))
a.loc[a.Target=="N1_int", "Target"]= name_N1_int.format(round(alpha,2))
a.loc[a.Target=="new_cases", "Target"]= name_new_cases


a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

hlinedf= pd.DataFrame({'Target': [name_N1C_int.format(round(alpha,2)),name_N1_int.format(round(alpha,2)), name_new_cases],
        'h_val': [N1_LoD/1000,N1_LoD/1000,0.999], 'color':['black','black','white']
        }, columns = ['Target', 'h_val', 'color'])

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_line(a, aes(x='date_sampling', y='model', color='Target'), size=lw)+
geom_hline(hlinedf,aes(yintercept='h_val'), linetype='dashed', color=hlinedf.color)+
ylab('')+
xlab("")+
scale_color_cmap_d('viridis')+
scale_y_log10()+
facet_wrap('~Target', ncol=1)+ #, 
theme_classic()+ theme(legend_position='none', strip_text_x = element_text(margin={'t': 15}), axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6, 10)) )



# #title for the plot
# n='K_loess_alpha_var' 
# plot1=n  +'.pdf'
# #path for the plot
# path=os.path.join(dir_test, plot1)
# #save the plot


# plt.save(path)


e=a.copy()
e["location"]="E"

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/ipykernel/__main__.py:14: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_pointrange : Removed 115 rows containing missing values.
# <ggplot: (-9223372036524776248)>

# %%
a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique()
qpcr_int[(qpcr_int.sample_code==code) &(qpcr_int.N1_n>0)][["date_sampling","N1_n","N1_int","N1C_int"]].sort_values("date_sampling")
len(a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique())== pE
# Out:
# True

# %% [markdown]
# ## San Quentin

# %% [markdown]
# #### Old plots

# %% [markdown]
# ##### Orig data exploration

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="N"]
# a=a[a.interceptor=='SQ']

# a=a[a.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
# # a=a[a.date_sampling < pd.to_datetime('2020/09/14', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]
# a=a[a.Target!= "NH4_mgL"].copy() #not there
# a=a[a.Target!= "COD_mgL"].copy() #not there
# a=a[a.Target!= "cBOD_mgL"].copy() #not there


# no=["cBOD_mgL","NH4_mgL", "COD_mgL","GFP","bCoV", "seven_day_moving_total_new_cases","population"]
# a=a[~a.Target.isin(no)].copy() #not there

# category_order=["N1","bact","18S","crAss","PMMoV","flow_MGD","TSS_mgL", "new_cases",'active_cases', 'total_tests', "released_while_active","resolved","deaths", "fraction_positive"] 
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# geom_smooth(method='loess')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target',nrow=3, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15, 8)) )

# plt

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="Y"]
# a=a[a.interceptor=='SQ']

# a=a[a.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]


# # no=["N1_NH4", "N1_COD","N1_cBOD", "seven_day_moving_total_new_cases","population","N1_TSS"]
# no=["N1_NH4", "N1_COD","N1_cBOD", "seven_day_moving_total_new_cases","population","N1_TSS", "N1_bact","N1_18S","N1_PMMoV","N1_flow"]
# a=a[~a.Target.isin(no)].copy() #not there
# # category_order=["N1","N1_bact","N1_18S","N1_crAss","N1_PMMoV","N1_flow", "new_cases",'active_cases', 'total_tests', "released_while_active","resolved","deaths", "fraction_positive"]
# category_order=["N1","N1_crAss", "new_cases",'active_cases', 'total_tests', "fraction_positive", "released_while_active","resolved","deaths"]
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)


# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# # geom_smooth(method='loess')+
#     geom_line()+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target',ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 27)) )

# plt

# %% [markdown]
# ##### Smoothing with different spans for geom_smooth

# %%
# a=qpcr_long_dict["B_B_SQ"]
# a=a[~np.isnan(a.value)]

# # colors
# cmap = cm.get_cmap('viridis', 8)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int","N1_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# alpha= [0.65, 0.7,0.75,0.8,0.85,0.9,0.95,1]

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# # geom_smooth(method='loess', span= 0.65, se=False) +
# geom_point(a, aes(x='date_sampling', y='value'))+
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_hline(yintercept=N1_LoD, linetype='dashed')+
# geom_hline(yintercept=4000, linetype='dashed')+
# ylab('')+
# xlab("")+
# scale_y_log10()+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5, 7)) )



# # #title for the plot
# # n='SQ_loess_alpha_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # plt.save(path)

# plt

# %% [markdown]
# ##### Smoothing with pchip

# %%
# a=qpcr_pchip_dict["B_B_SQ"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1C_')]
# a=a[a.Target!= "N1_7D"]


# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1_int'))+
# # geom_line()+
# ylab('N1 gc/L')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='SQ_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# a=qpcr_pchip_dict["B_B_SQ"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1_')]
# a=a[a.Target!= "N1C_7D"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1C_int'))+
# # geom_line()+
# ylab('N1 normalized to crAss')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='SQ_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# b=wfsc_norm[["interceptor","N1",'N1_crAss',"new_cases", "active_cases","date_sampling"]].copy()
# b=b[b.interceptor=='SQ']

# b=b[b.date_sampling > pd.to_datetime('2020/06/01', format = '%Y/%m/%d')]
# b=b[b.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]
# b=b[~np.isnan(b.N1)]

# # grangercausalitytests(b[['N1', 'new_cases']], maxlag=2)
# # grangercausalitytests(b[['N1', 'active_cases']], maxlag=2)

# %% [markdown]
# #### Granger test

# %% [markdown]
# ##### Stationarity and autocorrelation

# %%
test=qpcr_dict["B_B_SQ"].reset_index(drop=True)
test=test[~np.isnan(test.N1_int)]
test_col=test[["N1_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -350.820544
# p-value: 0.000000
# Critical Values:
# 	1%: -6.045
# 	5%: -3.929
# 	10%: -2.987
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036525072629)>

# %%
test=qpcr_dict["B_B_SQ"].reset_index(drop=True)
test=test[~np.isnan(test.N1C_int)]
test_col=test[["N1C_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1C_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1C_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -607.483311
# p-value: 0.000000
# Critical Values:
# 	1%: -6.045
# 	5%: -3.929
# 	10%: -2.987
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036523816956)>

# %%
test=qpcr_dict["B_B_SQ"].reset_index(drop=True)
test=test[~np.isnan(test.new_cases)]
test_col=test[["cases_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='cases_2diff'))+
geom_point(test, aes(x='date_sampling', y='new_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -8.611684
# p-value: 0.000000
# Critical Values:
# 	1%: -3.470
# 	5%: -2.879
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036523639657)>

# %%
test=qpcr_dict["B_B_SQ"].reset_index(drop=True)
test=test[~np.isnan(test.pop_normalized_cases)]
test_col=test[["casesP_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='casesP_2diff'))+
geom_point(test, aes(x='date_sampling', y='pop_normalized_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -7.344474
# p-value: 0.000000
# Critical Values:
# 	1%: -3.486
# 	5%: -2.886
# 	10%: -2.580
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036524919166)>

# %% [markdown]
# ##### stat test

# %%
#can only run this with a start of at least 10 (thus 8 pts after differencing)
b=qpcr_dict["B_B_SQ"].reset_index(drop=True)[["N1_2diff",'cases_2diff', "date_sampling"]].sort_values('date_sampling').copy()
b=b.dropna()

c=qpcr_dict["B_B_SQ"].reset_index(drop=True)[["N1C_2diff",'casesP_2diff', "date_sampling"]].sort_values('date_sampling').copy()
c=c.dropna()

# grangercausalitytests(b[["N1_2diff",'cases_2diff']], maxlag=2)
# grangercausalitytests(c[["N1C_2diff", 'casesP_2diff',]], maxlag=2)

# %% [markdown]
# #### Smoothing with loess

# %%
code="B_B_SQ"
a=qpcr_loess_dict[code]

a.points=pd.to_numeric(a.points)
a['alpha_v']=a.points/(pK-1)
a['alpha_rounded']=a.alpha_v.apply(lambda x: round(x,2) ).astype(object)

plt = (ggplot(a, aes(x='date_sampling', y='residuals')) + 
    geom_point()+
    ylab("K_K_INF loess residuals")+
    geom_smooth(method='loess', span= 1, se=False)+
    facet_grid('Target~points +alpha_rounded ', scales='free_y')+
    xlab("")+
    theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15,5)) )
    
#choosing 6 for N1 and crass
pts=6
alpha=pd.to_numeric(a.loc[a.points==pts, "alpha_v"].unique().item())

plt
# Out:
# <ggplot: (-9223372036523780166)>

# %%
a
# Out:
#    date_sampling  Target  points  residuals    y_pred  alpha_v alpha_rounded
# 0     2020-07-01      N1       1   0.00E+00  4.89E+06 8.33E-02      8.00E-02
# 1     2020-07-08      N1       1   0.00E+00  9.07E+05 8.33E-02      8.00E-02
# 2     2020-07-15      N1       1   0.00E+00  1.33E+06 8.33E-02      8.00E-02
# 3     2020-07-28      N1       1   0.00E+00  1.95E+05 8.33E-02      8.00E-02
# 4     2020-08-04      N1       1   0.00E+00  2.00E+03 8.33E-02      8.00E-02
# ..           ...     ...     ...        ...       ...      ...           ...
# 95    2020-08-11  N1_18S      10  -1.18E+05  1.20E+05 8.33E-01      8.30E-01
# 96    2020-08-18  N1_18S      10  -6.20E+04  6.40E+04 8.33E-01      8.30E-01
# 97    2020-08-25  N1_18S      10  -2.11E+04  2.31E+04 8.33E-01      8.30E-01
# 98    2020-09-01  N1_18S      10   1.31E+04 -1.11E+04 8.33E-01      8.30E-01
# 99    2020-09-15  N1_18S      10   6.68E+04 -6.48E+04 8.33E-01      8.30E-01
#
# [500 rows x 7 columns]

# %%
loess=qpcr_loess_dict[code].copy()

loess_N1=loess[loess.Target=="N1"].copy()
loess_N1["Target"]="N1_int"
loess_N1_int= loess_N1.loc[loess_N1.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1_int=loess_N1_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1_int["y_pred_int"]=loess_N1_int["y_pred"].interpolate(method='linear')


loess_N1C=loess[loess.Target=="N1_crAss"].copy()
loess_N1C["Target"]="N1C_int"
loess_N1C_int= loess_N1C.loc[loess_N1C.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1C_int=loess_N1C_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1C_int["y_pred_int"]=loess_N1C_int["y_pred"].interpolate(method='linear')

loess_N1=loess_N1.reset_index(drop=True)
loess_N1C=loess_N1C.reset_index(drop=True)

pt=loess_N1.alpha_v.unique()


#merge lowess and case data models to create a dataframe of models
case_model_lookup=qpcr_int[qpcr_int.sample_code==code][["date_sampling","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases"]].copy()
models_merge= loess_N1C_int.copy().reset_index().drop("y_pred",axis=1)
models_merge.columns=["date_sampling", "N1C_int"]

models_int=loess_N1_int.reset_index().merge(case_model_lookup, how='left', on='date_sampling')
models_int["mvga_7D_new_cases"]= models_int["seven_day_moving_total_new_cases"]/7
models_int["mvga_7D_active_cases"]= models_int["seven_day_moving_total_active_cases"]/7
models_int=models_int.drop(["y_pred","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases" ], axis=1)
models_int.columns=["date_sampling","N1_int", "new_cases", "active_cases"]
models_int=models_int.merge(models_merge, how='left', on='date_sampling')

models_int_long=models_int.copy().melt(id_vars="date_sampling", value_vars=["N1_int", "new_cases", "active_cases", "N1C_int"], var_name="Target", value_name="model")

# %% [markdown]
# #### Final plot comparison to new cases

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
a.Target.unique()
a=a[(a.date_sampling >= start_dict[code]) & (a.date_sampling <= end_dict[code])]

a=a.merge(models_int_long, how='left', on=["date_sampling", "Target"])
a.loc[a.Target== "N1_int", "value"]= a.loc[a.Target== "N1_int", "value"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "value"]= a.loc[a.Target== "N1C_int", "value"]/1000 #convert to same om as above ONLY when normalized to the median
a.loc[a.Target== "N1_int", "model"]= a.loc[a.Target== "N1_int", "model"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "model"]= a.loc[a.Target== "N1C_int", "model"]/1000 #convert to same om as above ONLY when normalized to the median

t=["N1C_int","N1_int","new_cases"]
a=a[a.Target.isin(t)]
a.Target_p=a.Target
a.loc[a.Target=="N1C_int", "Target"]= name_N1C_int.format(round(alpha,2))
a.loc[a.Target=="N1_int", "Target"]= name_N1_int.format(round(alpha,2))
a.loc[a.Target=="new_cases", "Target"]= name_new_cases


a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

hlinedf= pd.DataFrame({'Target': [name_N1C_int.format(round(alpha,2)),name_N1_int.format(round(alpha,2)), name_new_cases],
        'h_val': [N1_LoD/1000,N1_LoD/1000,0.999], 'color':['black','black','white']
        }, columns = ['Target', 'h_val', 'color'])

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_line(a, aes(x='date_sampling', y='model', color='Target'), size=lw)+
geom_hline(hlinedf,aes(yintercept='h_val'), linetype='dashed', color=hlinedf.color)+
ylab('')+
xlab("")+
scale_color_cmap_d('viridis')+
scale_y_log10()+
facet_wrap('~Target', ncol=1, scales="free_y")+ #, 
theme_classic()+ theme(legend_position='none', strip_text_x = element_text(margin={'t': 15}), axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6, 10)) )



# #title for the plot
# n='K_loess_alpha_var' 
# plot1=n  +'.pdf'
# #path for the plot
# path=os.path.join(dir_test, plot1)
# #save the plot


# plt.save(path)


sq=a.copy()
sq["location"]="SQ"

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/ipykernel/__main__.py:14: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning:
#
# divide by zero encountered in log10
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_pointrange : Removed 95 rows containing missing values.
# <ggplot: (-9223372036521419534)>

# %%
a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique()
qpcr_int[(qpcr_int.sample_code==code) &(qpcr_int.N1_n>0)][["date_sampling","N1_n","N1_int","N1C_int"]].sort_values("date_sampling")
len(a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique())== pSQ
# Out:
# True

# %% [markdown]
# #### Final plot comparison to active cases

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
a.Target.unique()
a=a[(a.date_sampling >= start_dict[code]) & (a.date_sampling <= end_dict[code])]

a=a.merge(models_int_long, how='left', on=["date_sampling", "Target"])
a.loc[a.Target== "N1_int", "value"]= a.loc[a.Target== "N1_int", "value"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "value"]= a.loc[a.Target== "N1C_int", "value"]/1000 #convert to same om as above ONLY when normalized to the median
a.loc[a.Target== "N1_int", "model"]= a.loc[a.Target== "N1_int", "model"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "model"]= a.loc[a.Target== "N1C_int", "model"]/1000 #convert to same om as above ONLY when normalized to the median

t=["N1C_int","N1_int","active_cases"]
a=a[a.Target.isin(t)]
a.Target_p=a.Target
a.loc[a.Target=="N1C_int", "Target"]= name_N1C_int.format(round(alpha,2))
a.loc[a.Target=="N1_int", "Target"]= name_N1_int.format(round(alpha,2))
a.loc[a.Target=="active_cases", "Target"]= name_active_cases


a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

hlinedf= pd.DataFrame({'Target': [name_N1C_int.format(round(alpha,2)),name_N1_int.format(round(alpha,2)), name_active_cases],
        'h_val': [N1_LoD/1000,N1_LoD/1000,0.999], 'color':['black','black','white']
        }, columns = ['Target', 'h_val', 'color'])

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_line(a, aes(x='date_sampling', y='model', color='Target'), size=lw)+
geom_hline(hlinedf,aes(yintercept='h_val'), linetype='dashed', color=hlinedf.color)+
ylab('')+
xlab("")+
scale_color_cmap_d('viridis')+
scale_y_log10()+
facet_wrap('~Target', ncol=1, scales="free_y")+ #, 
theme_classic()+ theme(legend_position='none', strip_text_x = element_text(margin={'t': 15}), axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6, 10)) )



# #title for the plot
# n='K_loess_alpha_var' 
# plot1=n  +'.pdf'
# #path for the plot
# path=os.path.join(dir_test, plot1)
# #save the plot


# plt.save(path)

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/ipykernel/__main__.py:14: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_pointrange : Removed 95 rows containing missing values.
# <ggplot: (333494371)>

# %%
a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique()
qpcr_int[(qpcr_int.sample_code==code) &(qpcr_int.N1_n>0)][["date_sampling","N1_n","N1_int","N1C_int"]].sort_values("date_sampling")
len(a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique())== pSQ
# Out:
# True

# %% [markdown]
# ## S68

# %% [markdown]
# #### Old plots

# %% [markdown]
# ##### Orig data exploration

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="Y"]
# a=a[a.interceptor=='S68']

# a=a[a.date_sampling > pd.to_datetime('2020/05/01', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]

# a.Target.unique()

# # no=["N1_NH4", "N1_COD","N1_cBOD", "seven_day_moving_total_new_cases","population","N1_TSS"]
# no=["N1_NH4", "N1_COD","N1_cBOD", "seven_day_moving_total_new_cases","population","N1_TSS", "N1_PMMoV"]
# a=a[~a.Target.isin(no)].copy() #not there
# # category_order=["N1","N1_crAss","N1_PMMoV","new_cases"]
# category_order=["N1","N1_crAss","new_cases"]
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)


# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# geom_line()+
# # geom_smooth(method='loess')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target',nrow=3, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,9)) )

# plt

# %% [markdown]
# ##### Smoothing with different spans for geom_smooth

# %%
# a=qpcr_long_dict["C_C_S68"]
# a=a[~np.isnan(a.value)]

# # colors
# cmap = cm.get_cmap('viridis', 11)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int","N1_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# alpha= [0.35, 0.45, 0.55, 0.65, 0.7,0.75,0.8,0.85,0.9,0.95,1]

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# # geom_smooth(method='loess', span= 0.35, se=False) +
# geom_hline(yintercept=N1_LoD, linetype='dashed')+
# geom_hline(yintercept=4000, linetype='dashed')+       
# geom_point(a, aes(x='date_sampling', y='value'))+
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# ylab('')+
# xlab("")+
# scale_y_log10()+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5, 7)) )



# # # title for the plot
# # n='S68_loess_alpha_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # plt.save(path)

# plt

# %% [markdown]
# ##### Smoothing with pchip

# %%
# a=qpcr_pchip_dict["C_C_S68"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1C_')]
# # a=a[a.Target!= "N1_7D"]


# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1_int'))+
# # geom_line()+
# ylab('N1 gc/L')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='SQ_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# a=qpcr_pchip_dict["C_C_S68"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1_')]
# # a=a[a.Target!= "N1C_7D"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1C_int'))+
# # geom_line()+
# ylab('N1 normalized to crAss')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='SQ_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %% [markdown]
# #### Granger test

# %% [markdown]
# ##### Stationarity and autocorrelation

# %%
test=qpcr_dict["C_C_S68"].reset_index(drop=True)
test=test[~np.isnan(test.N1_int)]
test_col=test[["N1_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -2.628225
# p-value: 0.087303
# Critical Values:
# 	1%: -4.223
# 	5%: -3.189
# 	10%: -2.730
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (333637682)>

# %%
test=qpcr_dict["C_C_S68"].reset_index(drop=True)
test=test[~np.isnan(test.N1C_int)]
test_col=test[["N1C_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1C_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1C_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -0.577106
# p-value: 0.876072
# Critical Values:
# 	1%: -4.332
# 	5%: -3.233
# 	10%: -2.749
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (333695289)>

# %%
test=qpcr_dict["C_C_S68"].reset_index(drop=True)
test=test[~np.isnan(test.new_cases)]
test_col=test[["cases_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='cases_2diff'))+
geom_point(test, aes(x='date_sampling', y='new_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -8.836608
# p-value: 0.000000
# Critical Values:
# 	1%: -3.470
# 	5%: -2.879
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (333732521)>

# %%
test=qpcr_dict["C_C_S68"].reset_index(drop=True)
test=test[~np.isnan(test.pop_normalized_cases)]
test_col=test[["casesP_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='casesP_2diff'))+
geom_point(test, aes(x='date_sampling', y='pop_normalized_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -8.836608
# p-value: 0.000000
# Critical Values:
# 	1%: -3.470
# 	5%: -2.879
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036520986329)>

# %% [markdown]
# ##### stat test

# %%
#can only run this with a start of at least 10 (thus 8 pts after differencing)
b=qpcr_dict["C_C_S68"].reset_index(drop=True)[["N1_2diff",'cases_2diff', "date_sampling"]].sort_values('date_sampling').copy()
b=b.dropna()

c=qpcr_dict["C_C_S68"].reset_index(drop=True)[["N1C_2diff",'casesP_2diff', "date_sampling"]].sort_values('date_sampling').copy()
c=c.dropna()

grangercausalitytests(b[["N1_2diff",'cases_2diff']], maxlag=2)
grangercausalitytests(c[["N1C_2diff", 'casesP_2diff',]], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7929  , p=0.3883  , df_denom=14, df_num=1
# ssr based chi2 test:   chi2=0.9629  , p=0.3265  , df=1
# likelihood ratio test: chi2=0.9366  , p=0.3332  , df=1
# parameter F test:         F=0.7929  , p=0.3883  , df_denom=14, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5013  , p=0.6190  , df_denom=11, df_num=2
# ssr based chi2 test:   chi2=1.4582  , p=0.4823  , df=2
# likelihood ratio test: chi2=1.3955  , p=0.4977  , df=2
# parameter F test:         F=0.5013  , p=0.6190  , df_denom=11, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1077  , p=0.7476  , df_denom=14, df_num=1
# ssr based chi2 test:   chi2=0.1308  , p=0.7176  , df=1
# likelihood ratio test: chi2=0.1303  , p=0.7181  , df=1
# parameter F test:         F=0.1077  , p=0.7476  , df_denom=14, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ...

# %% [markdown]
# #### Smoothing with loess

# %%
code="C_C_S68"
a=qpcr_loess_dict[code]

a.points=pd.to_numeric(a.points)
a['alpha_v']=a.points/(pK-1)
a['alpha_rounded']=a.alpha_v.apply(lambda x: round(x,2) ).astype(object)

plt = (ggplot(a, aes(x='date_sampling', y='residuals')) + 
    geom_point()+
    ylab("K_K_INF loess residuals")+
    geom_smooth(method='loess', span= 1, se=False)+
    facet_grid('Target~points +alpha_rounded ', scales='free_y')+
    xlab("")+
    theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15,2)) )
    
#choosing 8 for N1 and crass
pts=8
alpha=pd.to_numeric(a.loc[a.points==pts, "alpha_v"].unique().item())

plt
# Out:
# <ggplot: (333840490)>

# %%
loess=qpcr_loess_dict[code].copy()

loess_N1=loess[loess.Target=="N1"].copy()
loess_N1["Target"]="N1_int"
loess_N1_int= loess_N1.loc[loess_N1.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1_int=loess_N1_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1_int["y_pred_int"]=loess_N1_int["y_pred"].interpolate(method='linear')


loess_N1C=loess[loess.Target=="N1_crAss"].copy()
loess_N1C["Target"]="N1C_int"
loess_N1C_int= loess_N1C.loc[loess_N1C.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1C_int=loess_N1C_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1C_int["y_pred_int"]=loess_N1C_int["y_pred"].interpolate(method='linear')

loess_N1=loess_N1.reset_index(drop=True)
loess_N1C=loess_N1C.reset_index(drop=True)

pt=loess_N1.alpha_v.unique()


#merge lowess and case data models to create a dataframe of models
case_model_lookup=qpcr_int[qpcr_int.sample_code==code][["date_sampling","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases"]].copy()
models_merge= loess_N1C_int.copy().reset_index().drop("y_pred",axis=1)
models_merge.columns=["date_sampling", "N1C_int"]

models_int=loess_N1_int.reset_index().merge(case_model_lookup, how='left', on='date_sampling')
models_int["mvga_7D_new_cases"]= models_int["seven_day_moving_total_new_cases"]/7
models_int["mvga_7D_active_cases"]= models_int["seven_day_moving_total_active_cases"]/7
models_int=models_int.drop(["y_pred","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases" ], axis=1)
models_int.columns=["date_sampling","N1_int", "new_cases", "active_cases"]
models_int=models_int.merge(models_merge, how='left', on='date_sampling')

models_int_long=models_int.copy().melt(id_vars="date_sampling", value_vars=["N1_int", "new_cases", "active_cases", "N1C_int"], var_name="Target", value_name="model")

# %% [markdown]
# #### Final Plot

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
a.Target.unique()
a=a[(a.date_sampling >= start_dict[code]) & (a.date_sampling <= end_dict[code])]

a=a.merge(models_int_long, how='left', on=["date_sampling", "Target"])
a.loc[a.Target== "N1_int", "value"]= a.loc[a.Target== "N1_int", "value"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "value"]= a.loc[a.Target== "N1C_int", "value"]/1000 #convert to same om as above ONLY when normalized to the median
a.loc[a.Target== "N1_int", "model"]= a.loc[a.Target== "N1_int", "model"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "model"]= a.loc[a.Target== "N1C_int", "model"]/1000 #convert to same om as above ONLY when normalized to the median

t=["N1C_int","N1_int","new_cases"]
a=a[a.Target.isin(t)]
a.Target_p=a.Target
a.loc[a.Target=="N1C_int", "Target"]= name_N1C_int.format(round(alpha,2))
a.loc[a.Target=="N1_int", "Target"]= name_N1_int.format(round(alpha,2))
a.loc[a.Target=="new_cases", "Target"]= name_new_cases


a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

hlinedf= pd.DataFrame({'Target': [name_N1C_int.format(round(alpha,2)),name_N1_int.format(round(alpha,2)), name_new_cases],
        'h_val': [N1_LoD/1000,N1_LoD/1000,10], 'color':['black','black','black']
        }, columns = ['Target', 'h_val', 'color'])

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_line(a, aes(x='date_sampling', y='model', color='Target'), size=lw)+
geom_hline(hlinedf,aes(yintercept='h_val'), linetype='dashed', color=hlinedf.color)+
ylab('')+
xlab("")+
scale_color_cmap_d('viridis')+
scale_y_log10()+
facet_wrap('~Target', ncol=1)+ #, 
theme_classic()+ theme(legend_position='none', strip_text_x = element_text(margin={'t': 15}), axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6, 10)) )



# #title for the plot
# n='K_loess_alpha_var' 
# plot1=n  +'.pdf'
# #path for the plot
# path=os.path.join(dir_test, plot1)
# #save the plot


# plt.save(path)

s=a.copy()
s["location"]="S68"

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/ipykernel/__main__.py:14: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_pointrange : Removed 186 rows containing missing values.
# <ggplot: (-9223372036523824938)>

# %%
a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique()
qpcr_int[(qpcr_int.sample_code==code) &(qpcr_int.N1_n>0)][["date_sampling","N1_n","N1_int","N1C_int"]].sort_values("date_sampling")
len(a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique())== pS
# Out:
# True

# %% [markdown]
# ## N49

# %% [markdown]
# #### Old plots

# %% [markdown]
# ##### Orig data exploration

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="Y"]
# a=a[a.interceptor=='N49']

# a=a[a.date_sampling > pd.to_datetime('2020/05/01', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]

# a.Target.unique()

# no=["N1_NH4", "N1_COD","N1_cBOD","N1_PMMoV", "seven_day_moving_total_new_cases","population","N1_TSS"]
# a=a[~a.Target.isin(no)].copy() #not there
# category_order=["N1","N1_crAss","new_cases"]
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)


# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# geom_line()+
# # geom_smooth(method='loess')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target',nrow=3, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,9)) )

# plt

# %% [markdown]
# ##### Smoothing with different spans for geom_smooth

# %%
# a=qpcr_long_dict["C_C_N49"]
# a=a[~np.isnan(a.value)]

# # colors
# cmap = cm.get_cmap('viridis', 9)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int","N1_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# alpha= [0.55, 0.65, 0.7,0.75,0.8,0.85,0.9,0.95,1]

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# # geom_smooth(method='loess', span= 0.55, se=False) +
# geom_point(a, aes(x='date_sampling', y='value'))+
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_hline(yintercept=N1_LoD, linetype='dashed')+
# geom_hline(yintercept=4000, linetype='dashed')+       
# ylab('')+
# xlab("")+
# scale_y_log10()+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5, 7)) )



# # #title for the plot
# # n='N49_loess_alpha_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # plt.save(path)

# plt

# %% [markdown]
# ##### Smoothing with pchip

# %%
# a=qpcr_pchip_dict["C_C_N49"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1C_')]
# a=a[a.Target!= "N1_7D"]


# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1_int'))+
# # geom_line()+
# ylab('N1 gc/L')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='N49_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# a=qpcr_pchip_dict["C_C_N49"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1_')]
# a=a[a.Target!= "N1C_7D"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1C_int'))+
# # geom_line()+
# ylab('N1 normalized to crAss')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='N49_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %% [markdown]
# #### Granger test

# %% [markdown]
# ##### Stationarity and autocorrelation

# %%
test=qpcr_dict["C_C_N49"].reset_index(drop=True)
test=test[~np.isnan(test.N1_int)]
test_col=test[["N1_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -4.001947
# p-value: 0.001400
# Critical Values:
# 	1%: -4.138
# 	5%: -3.155
# 	10%: -2.714
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036523658720)>

# %%
test=qpcr_dict["C_C_N49"].reset_index(drop=True)
test=test[~np.isnan(test.N1C_int)]
test_col=test[["N1C_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='N1C_2diff'))+
geom_point(test, aes(x='date_sampling', y='N1C_int'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -2.670887
# p-value: 0.079213
# Critical Values:
# 	1%: -4.473
# 	5%: -3.290
# 	10%: -2.772
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036525648843)>

# %%
test=qpcr_dict["C_C_N49"].reset_index(drop=True)
test=test[~np.isnan(test.new_cases)]
test_col=test[["cases_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='cases_2diff'))+
geom_point(test, aes(x='date_sampling', y='new_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -9.626229
# p-value: 0.000000
# Critical Values:
# 	1%: -3.470
# 	5%: -2.879
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (-9223372036525602679)>

# %%
test=qpcr_dict["C_C_N49"].reset_index(drop=True)
test=test[~np.isnan(test.pop_normalized_cases)]
test_col=test[["casesP_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


plt = (ggplot() + 
geom_point(test, aes(x='date_sampling', y='casesP_2diff'))+
geom_point(test, aes(x='date_sampling', y='pop_normalized_cases'), color='red')+
# geom_smooth(method='loess')+
ylab('')+
xlab('')+
scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

plt
# Out:
# ADF Statistic: -9.626229
# p-value: 0.000000
# Critical Values:
# 	1%: -3.470
# 	5%: -2.879
# 	10%: -2.576
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (331252975)>

# %% [markdown]
# ##### stat test

# %%
#can only run this with a start of at least 10 (thus 8 pts after differencing)
b=qpcr_dict["C_C_N49"].reset_index(drop=True)[["N1_2diff",'cases_2diff', "date_sampling"]].sort_values('date_sampling').copy()
b=b.dropna()

c=qpcr_dict["C_C_N49"].reset_index(drop=True)[["N1C_2diff",'casesP_2diff', "date_sampling"]].sort_values('date_sampling').copy()
c=c.dropna()

grangercausalitytests(b[["N1_2diff",'cases_2diff']], maxlag=2)
grangercausalitytests(c[["N1C_2diff", 'casesP_2diff',]], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0407  , p=0.8435  , df_denom=12, df_num=1
# ssr based chi2 test:   chi2=0.0509  , p=0.8215  , df=1
# likelihood ratio test: chi2=0.0508  , p=0.8217  , df=1
# parameter F test:         F=0.0407  , p=0.8435  , df_denom=12, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4009  , p=0.0794  , df_denom=9, df_num=2
# ssr based chi2 test:   chi2=10.5806 , p=0.0050  , df=2
# likelihood ratio test: chi2=7.8806  , p=0.0194  , df=2
# parameter F test:         F=3.4009  , p=0.0794  , df_denom=9, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0003  , p=0.9860  , df_denom=12, df_num=1
# ssr based chi2 test:   chi2=0.0004  , p=0.9841  , df=1
# likelihood ratio test: chi2=0.0004  , p=0.9841  , df=1
# parameter F test:         F=0.0003  , p=0.9860  , df_denom=12, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ...

# %% [markdown]
# #### Smoothing with loess

# %%
code="C_C_N49"
a=qpcr_loess_dict[code]

a.points=pd.to_numeric(a.points)
a['alpha_v']=a.points/(pK-1)
a['alpha_rounded']=a.alpha_v.apply(lambda x: round(x,2) ).astype(object)

plt = (ggplot(a, aes(x='date_sampling', y='residuals')) + 
    geom_point()+
    ylab("K_K_INF loess residuals")+
    geom_smooth(method='loess', span= 1, se=False)+
    facet_grid('Target~points +alpha_rounded ', scales='free_y')+
    xlab("")+
    theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15,2)) )
    
#choosing 6 for N1 and crass
pts=6
alpha=pd.to_numeric(a.loc[a.points==pts, "alpha_v"].unique().item())

plt
# Out:
# <ggplot: (-9223372036521229210)>

# %%
loess=qpcr_loess_dict[code].copy()

loess_N1=loess[loess.Target=="N1"].copy()
loess_N1["Target"]="N1_int"
loess_N1_int= loess_N1.loc[loess_N1.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1_int=loess_N1_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1_int["y_pred_int"]=loess_N1_int["y_pred"].interpolate(method='linear')


loess_N1C=loess[loess.Target=="N1_crAss"].copy()
loess_N1C["Target"]="N1C_int"
loess_N1C_int= loess_N1C.loc[loess_N1C.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1C_int=loess_N1C_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1C_int["y_pred_int"]=loess_N1C_int["y_pred"].interpolate(method='linear')

loess_N1=loess_N1.reset_index(drop=True)
loess_N1C=loess_N1C.reset_index(drop=True)

pt=loess_N1.alpha_v.unique()


#merge lowess and case data models to create a dataframe of models
case_model_lookup=qpcr_int[qpcr_int.sample_code==code][["date_sampling","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases"]].copy()
models_merge= loess_N1C_int.copy().reset_index().drop("y_pred",axis=1)
models_merge.columns=["date_sampling", "N1C_int"]

models_int=loess_N1_int.reset_index().merge(case_model_lookup, how='left', on='date_sampling')
models_int["mvga_7D_new_cases"]= models_int["seven_day_moving_total_new_cases"]/7
models_int["mvga_7D_active_cases"]= models_int["seven_day_moving_total_active_cases"]/7
models_int=models_int.drop(["y_pred","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases" ], axis=1)
models_int.columns=["date_sampling","N1_int", "new_cases", "active_cases"]
models_int=models_int.merge(models_merge, how='left', on='date_sampling')

models_int_long=models_int.copy().melt(id_vars="date_sampling", value_vars=["N1_int", "new_cases", "active_cases", "N1C_int"], var_name="Target", value_name="model")

# %% [markdown]
# #### Final Plot

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
a.Target.unique()
a=a[(a.date_sampling >= start_dict[code]) & (a.date_sampling <= end_dict[code])]

a=a.merge(models_int_long, how='left', on=["date_sampling", "Target"])
a.loc[a.Target== "N1_int", "value"]= a.loc[a.Target== "N1_int", "value"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "value"]= a.loc[a.Target== "N1C_int", "value"]/1000 #convert to same om as above ONLY when normalized to the median
a.loc[a.Target== "N1_int", "model"]= a.loc[a.Target== "N1_int", "model"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "model"]= a.loc[a.Target== "N1C_int", "model"]/1000 #convert to same om as above ONLY when normalized to the median

t=["N1C_int","N1_int","new_cases"]
a=a[a.Target.isin(t)]
a.loc[a.Target=="N1C_int", "Target"]= name_N1C_int.format(round(alpha,2))
a.loc[a.Target=="N1_int", "Target"]= name_N1_int.format(round(alpha,2))
a.loc[a.Target=="new_cases", "Target"]= name_new_cases


a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

hlinedf= pd.DataFrame({'Target': [name_N1C_int.format(round(alpha,2)),name_N1_int.format(round(alpha,2)), name_new_cases],
        'h_val': [N1_LoD/1000,N1_LoD/1000,10], 'color':['black','black','black']
        }, columns = ['Target', 'h_val', 'color'])

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_line(a, aes(x='date_sampling', y='model', color='Target'), size=lw)+
geom_hline(hlinedf,aes(yintercept='h_val'), linetype='dashed', color=hlinedf.color)+
ylab('')+
xlab("")+
scale_color_cmap_d('viridis')+
scale_y_log10()+
facet_wrap('~Target', ncol=1)+ #, 
theme_classic()+ theme(legend_position='none', strip_text_x = element_text(margin={'t': 15}), axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6, 10)) )



# #title for the plot
# n='K_loess_alpha_var' 
# plot1=n  +'.pdf'
# #path for the plot
# path=os.path.join(dir_test, plot1)
# #save the plot


# plt.save(path)


n=a.copy()
n["location"]="N49"

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning:
#
# divide by zero encountered in log10
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning:
#
# invalid value encountered in log10
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_pointrange : Removed 183 rows containing missing values.
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning:
#
# geom_path: Removed 3 rows containing missing values.
# <ggplot: (330864511)>

# %%
a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique()
qpcr_int[(qpcr_int.sample_code==code) &(qpcr_int.N1_n>0)][["date_sampling","N1_n","N1_int","N1C_int"]].sort_values("date_sampling")
len(a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique())== pN
# Out:
# True

# %% [markdown]
# ## ADA

# %% [markdown]
# #### Old Plots

# %% [markdown]
# ##### Orig data exploration

# %%
# a=qpcr_averaged_merged_long
# a=a[a.normalized=="Y"]
# a=a[a.interceptor=='ADA']

# a=a[a.date_sampling > pd.to_datetime('2020/05/01', format = '%Y/%m/%d')]
# a=a[a.date_sampling < pd.to_datetime('2020/09/20', format = '%Y/%m/%d')]

# a.Target.unique()

# no=["N1_NH4", "N1_COD","N1_cBOD","N1_PMMoV", "seven_day_moving_total_new_cases","population","N1_TSS"]
# a=a[~a.Target.isin(no)].copy() #not there
# category_order=["N1","N1_crAss","new_cases"]
# a.Target=a.Target.astype('category').cat.reorder_categories(category_order)


# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# geom_point()+
# ylab('')+
# xlab("")+
# # geom_smooth(method='loess')+
# geom_line()+
# scale_y_continuous(labels=scientific_format(digits=2))+
# facet_wrap('~Target',nrow=3, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,9)) )

# plt

# %% [markdown]
# ##### Smoothing with different spans for geom_smooth

# %%
# a=qpcr_long_dict["C_C_ADA"]
# a=a[~np.isnan(a.value)]

# # colors
# cmap = cm.get_cmap('viridis', 10)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int","N1_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# alpha= [0.45, 0.55, 0.65, 0.7,0.75,0.8,0.85,0.9,0.95,1]

# plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
# # [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# geom_smooth(method='loess', span= 1, se=False) +
# geom_point(a, aes(x='date_sampling', y='value'))+
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_hline(yintercept=N1_LoD, linetype='dashed')+
# geom_hline(yintercept=4000, linetype='dashed')+
# ylab('')+
# xlab("")+
# scale_y_log10()+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(5, 7)) )



# # #title for the plot
# # n='ADA_loess_alpha_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # plt.save(path)

# plt

# %% [markdown]
# ##### Smoothing with pchip

# %%
# a=qpcr_pchip_dict["C_C_ADA"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1C_')]
# a=a[a.Target!= "N1_7D"]
# a=a[a.Target!= "N1_3D"]


# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1_int'))+
# # geom_line()+
# ylab('N1 gc/L')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='ADA_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %%
# a=qpcr_pchip_dict["C_C_ADA"]
# a=a[~np.isnan(a.value)]


# a=a[~a.Target.str.contains('N1_')]
# a=a[a.Target!= "N1C_7D"]
# a=a[a.Target!= "N1C_3D"]

# plt = (ggplot(a) + 
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# geom_line(aes(x='date_sampling', y='value', color='Target'), size=lw)+
# geom_point(aes(x='date_sampling', y='N1C_int'))+
# # geom_line()+
# ylab('N1 normalized to crAss')+
# xlab("")+
# scale_y_log10()+ 
# scale_color_cmap_d('viridis')+
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )



# # #title for the plot
# # n='ADA_pchip_interval_var' 
# # plot1=n  +'.pdf'
# # #path for the plot
# # path=os.path.join(dir_test, plot1)
# # #save the plot


# # # plt.save(path)

# plt

# %% [markdown]
# #### Granger test

# %% [markdown]
# ##### Stationarity and autocorrelation

# %%
test=qpcr_dict["C_C_ADA"].reset_index(drop=True)
test=test[~np.isnan(test.N1_int)]
test_col=test[["N1_2diff"]].dropna().copy()

# plot_acf(test_col)
# augmented_dickey_fuller_statistics(test_col)


# plt = (ggplot() + 
# geom_point(test, aes(x='date_sampling', y='N1_2diff'))+
# geom_point(test, aes(x='date_sampling', y='N1_int'), color='red')+
# # geom_smooth(method='loess')+
# ylab('')+
# xlab('')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# # facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

# plt

# %%
test=qpcr_dict["C_C_ADA"].reset_index(drop=True)
test=test[~np.isnan(test.N1C_int)]
test_col=test[["N1C_2diff"]].dropna().copy()

# plot_acf(test_col)
# augmented_dickey_fuller_statistics(test_col)


# plt = (ggplot() + 
# geom_point(test, aes(x='date_sampling', y='N1C_1diff'))+
# geom_point(test, aes(x='date_sampling', y='N1C_int'), color='red')+
# # geom_smooth(method='loess')+
# ylab('')+
# xlab('')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# # facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

# plt

# %%
test=qpcr_dict["C_C_ADA"].reset_index(drop=True)
test=test[~np.isnan(test.new_cases)]
test_col=test[["cases_2diff"]].dropna().copy()

# plot_acf(test_col)
# augmented_dickey_fuller_statistics(test_col)


# plt = (ggplot() + 
# geom_point(test, aes(x='date_sampling', y='cases_2diff'))+
# geom_point(test, aes(x='date_sampling', y='new_cases'), color='red')+
# # geom_smooth(method='loess')+
# ylab('')+
# xlab('')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# # facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

# plt

# %%
test=qpcr_dict["C_C_ADA"].reset_index(drop=True)
test=test[~np.isnan(test.pop_normalized_cases)]
test_col=test[["casesP_2diff"]].dropna().copy()

plot_acf(test_col)
augmented_dickey_fuller_statistics(test_col)


# plt = (ggplot() + 
# geom_point(test, aes(x='date_sampling', y='casesP_2diff'))+
# geom_point(test, aes(x='date_sampling', y='pop_normalized_cases'), color='red')+
# # geom_smooth(method='loess')+
# ylab('')+
# xlab('')+
# scale_y_continuous(labels=scientific_format(digits=2))+
# # facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4, 2)) )

# plt
# Out:
# ADF Statistic: -9.379079
# p-value: 0.000000
# Critical Values:
# 	1%: -3.469
# 	5%: -2.878
# 	10%: -2.576

# %% [markdown]
# ##### stat test

# %%
#can only run this with a start of at least 10 (thus 8 pts after differencing)
b=qpcr_dict["C_C_ADA"].reset_index(drop=True)[["N1_2diff",'cases_2diff', "date_sampling"]].sort_values('date_sampling').copy()
b=b.dropna()

c=qpcr_dict["C_C_ADA"].reset_index(drop=True)[["N1C_2diff",'casesP_2diff', "date_sampling"]].sort_values('date_sampling').copy()
c=c.dropna()

# grangercausalitytests(b[["N1_2diff",'cases_2diff']], maxlag=2)
# grangercausalitytests(c[["N1C_2diff", 'casesP_2diff',]], maxlag=2)

# %% [markdown]
# #### Smoothing with loess

# %%
code="C_C_ADA"
a=qpcr_loess_dict[code]

a.points=pd.to_numeric(a.points)
a['alpha_v']=a.points/(pK-1)
a['alpha_rounded']=a.alpha_v.apply(lambda x: round(x,2) ).astype(object)

plt = (ggplot(a, aes(x='date_sampling', y='residuals')) + 
    geom_point()+
    ylab("K_K_INF loess residuals")+
    geom_smooth(method='loess', span= 1, se=False)+
    facet_grid('Target~points +alpha_rounded ', scales='free_y')+
    xlab("")+
    theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(15,2)) )
    
#choosing 5 for N1 and crass
pts=5
alpha=pd.to_numeric(a.loc[a.points==pts, "alpha_v"].unique().item())

plt
# Out:
# <ggplot: (-9223372036525464509)>

# %%
loess=qpcr_loess_dict[code].copy()

loess_N1=loess[loess.Target=="N1"].copy()
loess_N1["Target"]="N1_int"
loess_N1_int= loess_N1.loc[loess_N1.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1_int=loess_N1_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1_int["y_pred_int"]=loess_N1_int["y_pred"].interpolate(method='linear')


loess_N1C=loess[loess.Target=="N1_crAss"].copy()
loess_N1C["Target"]="N1C_int"
loess_N1C_int= loess_N1C.loc[loess_N1C.alpha_v==alpha,].copy().set_index("date_sampling").drop(["points", "alpha_v", "residuals", "Target", "alpha_rounded"], axis=1)
loess_N1C_int=loess_N1C_int.resample('D').max() #max just places nans because adding dates not subtracting
loess_N1C_int["y_pred_int"]=loess_N1C_int["y_pred"].interpolate(method='linear')

loess_N1=loess_N1.reset_index(drop=True)
loess_N1C=loess_N1C.reset_index(drop=True)

pt=loess_N1.alpha_v.unique()


#merge lowess and case data models to create a dataframe of models
case_model_lookup=qpcr_int[qpcr_int.sample_code==code][["date_sampling","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases"]].copy()
models_merge= loess_N1C_int.copy().reset_index().drop("y_pred",axis=1)
models_merge.columns=["date_sampling", "N1C_int"]

models_int=loess_N1_int.reset_index().merge(case_model_lookup, how='left', on='date_sampling')
models_int["mvga_7D_new_cases"]= models_int["seven_day_moving_total_new_cases"]/7
models_int["mvga_7D_active_cases"]= models_int["seven_day_moving_total_active_cases"]/7
models_int=models_int.drop(["y_pred","seven_day_moving_total_new_cases", "seven_day_moving_total_active_cases" ], axis=1)
models_int.columns=["date_sampling","N1_int", "new_cases", "active_cases"]
models_int=models_int.merge(models_merge, how='left', on='date_sampling')

models_int_long=models_int.copy().melt(id_vars="date_sampling", value_vars=["N1_int", "new_cases", "active_cases", "N1C_int"], var_name="Target", value_name="model")

# %% [markdown]
# #### Final Plot

# %%
a=qpcr_long_dict[code].copy()
a=a[~np.isnan(a.value)]
a.Target.unique()
a=a[(a.date_sampling >= start_dict[code]) & (a.date_sampling <= end_dict[code])]

a=a.merge(models_int_long, how='left', on=["date_sampling", "Target"])
a.loc[a.Target== "N1_int", "value"]= a.loc[a.Target== "N1_int", "value"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "value"]= a.loc[a.Target== "N1C_int", "value"]/1000 #convert to same om as above ONLY when normalized to the median
a.loc[a.Target== "N1_int", "model"]= a.loc[a.Target== "N1_int", "model"]/1000 #convert to gc/mL
a.loc[a.Target== "N1C_int", "model"]= a.loc[a.Target== "N1C_int", "model"]/1000 #convert to same om as above ONLY when normalized to the median

t=["N1C_int","N1_int","new_cases"]
a=a[a.Target.isin(t)]
a.Target_p=a.Target
a.loc[a.Target=="N1C_int", "Target"]= name_N1C_int.format(round(alpha,2))
a.loc[a.Target=="N1_int", "Target"]= name_N1_int.format(round(alpha,2))
a.loc[a.Target=="new_cases", "Target"]= name_new_cases


a['ymax']=a.value * a.gstd
a['ymin']=a.value / a.gstd

hlinedf= pd.DataFrame({'Target': [name_N1C_int.format(round(alpha,2)),name_N1_int.format(round(alpha,2)), name_new_cases],
        'h_val': [N1_LoD/1000,N1_LoD/1000,10], 'color':['black','black','black']
        }, columns = ['Target', 'h_val', 'color'])

plt = (ggplot(a, aes(x='date_sampling', y='value')) + 
geom_point(a, aes(x='date_sampling', y='value'))+
geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
geom_line(a, aes(x='date_sampling', y='model', color='Target'), size=lw)+
geom_hline(hlinedf,aes(yintercept='h_val'), linetype='dashed', color=hlinedf.color)+
ylab('')+
xlab("")+
scale_color_cmap_d('viridis')+
scale_y_log10()+
facet_wrap('~Target', ncol=1)+ #, 
theme_classic()+ theme(legend_position='none', strip_text_x = element_text(margin={'t': 15}), axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6, 10)) )



# #title for the plot
# n='K_loess_alpha_var' 
# plot1=n  +'.pdf'
# #path for the plot
# path=os.path.join(dir_test, plot1)
# #save the plot


# plt.save(path)

ada=a.copy()
ada["location"]="ADA"

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/ipykernel/__main__.py:14: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning:
#
# divide by zero encountered in log10
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/plotnine/layer.py:467: PlotnineWarning:
#
# geom_pointrange : Removed 115 rows containing missing values.
# <ggplot: (-9223372036524686392)>

# %%
a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique()
qpcr_int[(qpcr_int.sample_code==code) &(qpcr_int.N1_n>0)][["date_sampling","N1_n","N1_int","N1C_int"]].sort_values("date_sampling")
len(a[a.Target==name_N1_int.format(round(alpha,2))].date_sampling.unique())== pA
# Out:
# True

# %% [markdown]
# ## Comparison

# %%
# ada=qpcr_long_dict["C_C_ADA"]
# ada["location"]="ADA"
# s=qpcr_long_dict["C_C_S68"]
# s["location"]="S68"
# n=qpcr_long_dict["C_C_N49"]
# n["location"]="N49"
# sq=qpcr_long_dict["B_B_SQ"]
# sq["location"]="SQ"
# k=qpcr_long_dict["K_K_INF"]
# k["location"]="K"
# e=qpcr_long_dict["E_E_INF"]
# e["location"]="E"


# a=ada.append(s)
# a=a.append(n)
# a=a.append(sq)
# a=a.append(k)
# a=a.append(e)
# a=a[~np.isnan(a.value)]

# # colors
# cmap = cm.get_cmap('viridis', 11)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# plt = (ggplot(a, aes(x='date_sampling', y='value', color="location")) + 
# # [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# geom_smooth(method='loess', span= 1, se=False) +
# geom_point(a, aes(x='date_sampling', y='value'))+
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# ylab('')+
# xlab("")+
# scale_y_log10()+
# scale_color_cmap_d('viridis')+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6,4)) )

# plt

# %%
a=ada.append(s)
a=a.append(n)
a=a.append(sq)
a=a.append(k)
a=a.append(e)
a=a[~np.isnan(a.value)]
a
# # colors
# cmap = cm.get_cmap('viridis', 11)    # PiYG
# colors=[]
# for i in range(cmap.N):
#     rgba = cmap(i)
#     # rgb2hex accepts rgb or rgba
#     colors.append(matplotlib.colors.rgb2hex(rgba))

# t=["N1C_int"]
# a=a[a.Target.isin(t)]
# a.loc[a.Target=="N1C_int", "Target"]= "N1 normalized to crAss"
# a.loc[a.Target=="N1_int", "Target"]= "N1 gc/L"


# plt = (ggplot(a, aes(x='date_sampling', y='value', color="location")) + 
# # [geom_smooth(method='loess', span= alpha[i], se=False, color=colors[i]) for i in range(0,7)] +
# geom_smooth(method='loess', span= 1, se=False) +
# geom_point(a, aes(x='date_sampling', y='value'))+
# # geom_pointrange(a, aes(x='date_sampling', y='value', ymin='ymin', ymax='ymax')) +
# ylab('')+
# xlab("")+
# scale_y_log10()+
# scale_color_cmap_d('viridis')+
# facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6,4)) )

# plt
# Out:
#     date_sampling location                                             Target  \
# 0      2020-05-28      ADA      N1 gc/mL\nwhere model is lowess alpha= 0.42\n
# 1      2020-06-02      ADA      N1 gc/mL\nwhere model is lowess alpha= 0.42\n
# 2      2020-06-09      ADA      N1 gc/mL\nwhere model is lowess alpha= 0.42\n
# 3      2020-06-16      ADA      N1 gc/mL\nwhere model is lowess alpha= 0.42\n
# 4      2020-06-30      ADA      N1 gc/mL\nwhere model is lowess alpha= 0.42\n
# ..            ...      ...                                                ...
# 251    2020-09-10        E  new cases per day unnormalized\nwhere model is...
# 252    2020-09-11        E  new cases per day unnormalized\nwhere model is...
# 253    2020-09-12        E  new cases per day unnormalized\nwhere model is...
# 254    2020-09-13        E  new cases per day unnormalized\nwhere model is...
# 255    2020-09-14        E  new cases per day unnormalized\nwhere model is...
#
# ...

# %%
a['log_transformed_value']=np.log10(a.value)

g = (ggplot(a,aes(x='date_sampling',y='location',fill='log_transformed_value'))+
     geom_tile(aes(width=0.95, height=0.95))+
     scale_fill_cmap('viridis')+ theme_classic()+ 
     theme(axis_text_x=element_text(rotation=45, hjust=1), 
           legend_position = 'right',
           plot_title = element_text(size=14),
           axis_text_y = element_text(size=6)))
print(g)
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning:
#
# divide by zero encountered in log10
# <ggplot: (329386139)>

# %%
ada=qpcr_long_dict["C_C_ADA"]
s=qpcr_long_dict["C_C_S68"]
n=qpcr_long_dict["C_C_N49"]
sq=qpcr_long_dict["B_B_SQ"]
k=qpcr_long_dict["K_K_INF"]
e=qpcr_long_dict["E_E_INF"]

a=ada.append(s)
a=a.append(n)
a=a.append(sq)
a=a.append(k)
a=a.append(e)
a=a[~np.isnan(a.value)]

# colors
cmap = cm.get_cmap('viridis', 11)    # PiYG
colors=[]
for i in range(cmap.N):
    rgba = cmap(i)
    # rgb2hex accepts rgb or rgba
    colors.append(matplotlib.colors.rgb2hex(rgba))

t=['pop_normalized_cases']
p=a[a.Target.isin(t)]

# a=["S", "E"]
# p=p[p.location.isin(a)]

plt = (ggplot(p, aes(x='date_sampling', y='value', color="location")) + 
# geom_smooth(method='loess', span= 0.5, se=False) +
geom_point(p, aes(x='date_sampling', y='value'))+
xlab("")+
scale_y_log10()+
scale_color_cmap_d('viridis')+
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6,4)) )

plt
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning:
#
# divide by zero encountered in log10
# <ggplot: (-9223372036523724067)>

# %%
p['log_transformed_pop_normalized_cases']=np.log10(p.value)
g = (ggplot(p,aes(x='date_sampling',y='location',fill='log_transformed_pop_normalized_cases'))+
     geom_tile(aes(width=0.95, height=0.95))+
     scale_fill_cmap('viridis')+ theme_classic()+ 
     theme(axis_text_x=element_text(rotation=45, hjust=1), 
           legend_position = 'right',
           plot_title = element_text(size=14),
           axis_text_y = element_text(size=6)))
print(g)
# Out:
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning:
#
# divide by zero encountered in log10
#
# /Users/owner/.pyenv/versions/py3.6.8_outlierutils/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ggplot: (331165192)>

# %%
t=['new_cases']
n=a[a.Target.isin(t)]

plt = (ggplot(n, aes(x='date_sampling', y='value', color="location")) + 
geom_smooth(method='loess', span= 0.5, se=False) +
geom_point(n, aes(x='date_sampling', y='value'))+
ylab('')+
xlab("")+
# scale_y_log10()+
facet_wrap('~Target', ncol=1, scales='free_y')+ #, 
scale_color_cmap_d('viridis')+
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6,4)) )

plt
# Out:
# <ggplot: (331670799)>

# %%
g = (ggplot(n,aes(x='date_sampling',y='location',fill='value'))+
     geom_tile(aes(width=0.95, height=0.95))+
     scale_fill_cmap('viridis')+ theme_classic()+ 
     theme(axis_text_x=element_text(rotation=45, hjust=1), 
           legend_position = 'right',
           plot_title = element_text(size=14),
           axis_text_y = element_text(size=6)))
print(g)
# Out:
# <ggplot: (329968220)>

# %% [markdown]
# # QA/QC

# %% [markdown]
# ## Outlier removal testing

# %%
a=qpcr_averaged_merged[~np.isnan(qpcr_averaged_merged.Quantity_mean)]
targets=["N1","crAss","GFP","bCoV","PMMoV"]
inters=["S68","N49","ADA","SQ", "int"]
a=a[(a.Target.isin(targets) )& a.interceptor.isin(inters)]
 

oldgrubbs, std_curve_oldgrubbs, dilution_expts_oldgrubbs,raw_outliers_flagged_oldgrubbs, control_oldgrubbs = process_qpcr_raw(qpcr_raw, 'median_only', master_curve, use_master_curve=False)
dixonsQ, std_curve_dixonsQ, dilution_expts_dixonsQ,raw_outliers_flagged_dixonsQ, control_dixonsQ = process_qpcr_raw(qpcr_raw, 'dixonsq_only', master_curve, use_master_curve=False)

# %% [markdown]
# ### No outlier removal

# %%
none=qpcr_processed[(qpcr_processed.plate_id.isin(plates))& qpcr_processed.Target.isin(targets)].copy()
none["quantity_CV"]= (none["Q_init_gstd"]-1)*100
none["method"]="No outlier removal"
b=10
fig = (ggplot(none, aes(x='quantity_CV')) +  geom_histogram(bins=b)+facet_wrap("~Target", scales="free_x")+ #, 
stat_bin(aes(y='stat(count)', label='stat(count)'), bins=b, geom='text',nudge_y=5) +
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(16,8)) )
fig

# %% [markdown]
# ### Grubb's scikit package

# %%
grubbs_sci=qpcr_processed[(qpcr_processed.plate_id.isin(plates))& qpcr_processed.Target.isin(targets)].copy()
grubbs_sci["quantity_CV"]= ((grubbs_sci["Quantity_std_combined_after"]-1)*100) 
grubbs_sci["method"]="Scikit Grubbs"
b=10

fig = (ggplot(grubbs_sci, aes(x='quantity_CV')) +  geom_histogram(bins=b)+facet_wrap("~Target", scales="free_x")+ #, 
stat_bin(aes(y='stat(count)', label='stat(count)'), bins=b, geom='text',nudge_y=5) +
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(16,8)) )
fig

# %% [markdown]
# ### Grubbs outlier utils

# %%
old_grubbs=oldgrubbs[(oldgrubbs.plate_id.isin(plates))& oldgrubbs.Target.isin(targets)].copy()
old_grubbs["quantity_CV"]= ((old_grubbs["Quantity_std_combined_after"]-1)*100) 
old_grubbs["method"]="Outlier Utils Grubbs (max)"
b=10

fig = (ggplot(old_grubbs, aes(x='quantity_CV')) +  geom_histogram(bins=b)+facet_wrap("~Target", scales="free_x")+ #, 
stat_bin(aes(y='stat(count)', label='stat(count)'), bins=b, geom='text',nudge_y=5) +
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(16,8)) )
fig

# %% [markdown]
# ### Lauren L's Dixon's Q

# %%
dixons_Q=dixonsQ[(dixonsQ.plate_id.isin(plates))& dixonsQ.Target.isin(targets)].copy()
dixons_Q["quantity_CV"]= ((dixons_Q["Quantity_std_combined_after"]-1)*100) 
dixons_Q["method"]="Lauren L's Dixon's Q"
b=10

fig = (ggplot(dixons_Q, aes(x='quantity_CV')) +  geom_histogram(bins=b)+facet_wrap("~Target", scales="free_x")+ #, 
stat_bin(aes(y='stat(count)', label='stat(count)'), bins=b, geom='text',nudge_y=5) +
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(16,8)) )
fig

# %% [markdown]
# ### All

# %%
all_methods=grubbs_sci.append(none)
all_methods=all_methods.append(old_grubbs)
all_methods=all_methods.append(dixons_Q)

category_order=["No outlier removal","Lauren L's Dixon's Q","Outlier Utils Grubbs (max)","Scikit Grubbs"]
all_methods.method=all_methods.method.astype('category').cat.reorder_categories(category_order)


raw_outliers_flagged_oldgrubbs[["grubbs_test","pass_dixonsq"]]=np.nan
raw_outliers_flagged_oldgrubbs["method"]="Outlier Utils Grubbs (max)"
raw_outliers_flagged_oldgrubbs["pass"]=raw_outliers_flagged_oldgrubbs["median_test"]
raw_outliers_flagged_dixonsQ[["median_test","grubbs_test"]]=np.nan
raw_outliers_flagged_dixonsQ["method"]="Lauren L's Dixon's Q"
raw_outliers_flagged_dixonsQ["pass"]=raw_outliers_flagged_dixonsQ["pass_dixonsq"]
raw_outliers_flagged_df[["median_test","pass_dixonsq"]]=np.nan
raw_outliers_flagged_df["method"]="Scikit Grubbs"
raw_outliers_flagged_df["pass"]=raw_outliers_flagged_df["grubbs_test"]


all_methods_raw=raw_outliers_flagged_oldgrubbs.append(raw_outliers_flagged_df)
all_methods_raw=all_methods_raw.append(raw_outliers_flagged_dixonsQ)

category_order=["Lauren L's Dixon's Q","Outlier Utils Grubbs (max)","Scikit Grubbs"]
all_methods_raw.method=all_methods_raw.method.astype('category').cat.reorder_categories(category_order)

# %%
a=all_methods
a['height']=-50
#heights for plotting labels



#get biological triplicate inf
b= a.groupby(["Target",'method']).agg(height=('height','min'),n=('quantity_CV','count')).reset_index()
b['n']='n= '+b['n'].astype('str')
a=a.merge(b)

fig = (ggplot(a) +geom_boxplot(a, aes(x='method', y='quantity_CV'))+ 
facet_wrap("~Target",ncol=1, scales="free_y")+
geom_text(aes(x ='method', y ='height',label='n'),ha='center', va='center')+
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,16)) )
fig

# %%
a=all_methods
a['height']=-50
#heights for plotting labels



#get biological triplicate inf
b= a.groupby(["Target",'method']).agg(height=('height','min'),n=('Quantity_mean','count')).reset_index()
b['n']='n= '+b['n'].astype('str')
a=a.merge(b)

fig = (ggplot(a) +geom_boxplot(a, aes(x='method', y='Quantity_mean'))+ 
facet_wrap("~Target",ncol=1, scales="free_y")+
geom_text(aes(x ='method', y ='height',label='n'),ha='center', va='center')+
scale_y_continuous(labels=scientific_format(digits=2))+
theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,16)) )
fig

# %%
pd.set_option('display.float_format', '{:.5E}'.format)

for plate in plates:
    a=all_methods_raw[all_methods_raw.plate_id==plate]
    a=a[a.Target!="Xeno"]
    a.loc[np.isnan(a.Cq), "Cq"]=0
    grouped_a=a.groupby(["sample_full","method"]).agg(total=('pass','count'), npass=('pass', 'sum') ).reset_index()
    grouped_a['fr_pass']= grouped_a['npass']/grouped_a['total']
    interesting_samps=grouped_a[grouped_a.fr_pass<1].sample_full.unique()
    a=a[a.sample_full.isin(interesting_samps)]
    a['pass']=a['pass'].astype('category')
    
    b=all_methods[all_methods.plate_id==plate]
    b=b[b.Target!="Xeno"]
    b.loc[np.isnan(b.Quantity_mean), "Quantity_mean"]=0
    b.loc[np.isnan(b.Cq_mean), "Cq_mean"]=0
    b=b[b.sample_full.isin(interesting_samps)]
    table=b.pivot(index=['sample_full'],columns='method', values='Quantity_mean')
    table.columns=["none","dixonsq","oldgrubbs","grubbs"]
    intresting_table=table[~((table['none']== table['grubbs'])&(table['none']== table['oldgrubbs'])&(table['none']== table['dixonsq']))]
    
    #plot  
    title="For {} and plate {}".format(list(a.Target.unique()), list(a.plate_id.unique()))
    fig1=(ggplot(a) + 
    geom_jitter(a, aes(x='sample_full', y='Cq',color='pass')) +   
    ylab('Cq')+
    scale_y_continuous(labels=scientific_format(digits=2))+
    facet_wrap('~method', nrow=1)+
    xlab('')+
    ggtitle(title)+
    theme_classic()+ theme(plot_title = element_text(size = 20, face = "bold"),axis_text_x=element_text(color='black',rotation=45, hjust=1), axis_text_y=element_text(color='black'),figure_size=(12,4)) )

    
    print(fig1) 

    fig2=(ggplot(b, aes(x='method', y='Quantity_mean',group='sample_full')) + 
    geom_point() +   
    geom_line()+
    ylab('Quantity mean')+
    scale_y_continuous(labels=scientific_format(digits=2))+
    facet_wrap('~sample_full', ncol=1, scales='free_y')+
    xlab('')+
    theme_classic()+ theme(axis_text_x=element_text(color='black',rotation=45, hjust=1), axis_text_y=element_text(color='black'),figure_size=(4,16)) )
    print(fig2)
    
    print(intresting_table)

# %% [markdown]
# ## Yields by target

# %%
a=qpcr_averaged_merged
# l=["A","N","S"]
# a=a[a.Interceptor.isin(l)]
a=a[~np.isnan(a.gc_per_L)]
a=a[~np.isnan(a.RNA_ng_ul_qubit_all)].copy()
a_full=a.copy()

# a['Target']=a['Target'].str.replace('N1','SARS-CoV-2 N1')
# a['Target']=a['Target'].astype('category')
# a['Target']=a['Target'].cat.reorder_categories(['SARS-CoV-2 N1','PMMoV'])


fig7s=(ggplot(a, aes(x='RNA_yield', y='gc_per_L', color='interceptor', shape='interceptor')) + 
geom_point(size=4, alpha=0.6)+
facet_wrap('~Target', scales='free_y', ncol=1)+
scale_y_continuous(labels=scientific_format(digits=2))+
xlab('RNA yield\n(total ng RNA per mL of wastewater)')+
ylab('concentration\n(gene copies per L)\n')+
theme_classic()+ theme( axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,10)) )

# fig.save("N1vRNA.pdf")
# files.download("N1vRNA.pdf") 
fig7s

# %%
a=qpcr_averaged_merged
# l=["A","N","S"]
# a=a[a.Interceptor.isin(l)]
a=a[~np.isnan(a.gc_per_L)]
a=a[~np.isnan(a.RNA_ng_ul_qubit_all)].copy()
a_full=a.copy()

# a['Target']=a['Target'].str.replace('N1','SARS-CoV-2 N1')
# a['Target']=a['Target'].astype('category')
# a['Target']=a['Target'].cat.reorder_categories(['SARS-CoV-2 N1','PMMoV'])


fig7s=(ggplot(a, aes(x='DNA_yield', y='gc_per_L', color='interceptor', shape='interceptor')) + 
geom_point(size=4, alpha=0.6)+
facet_wrap('~Target', scales='free_y', ncol=1)+
scale_y_continuous(labels=scientific_format(digits=2))+
xlab('DNA yield\n(total ng DNA per mL of wastewater)')+
ylab('concentration\n(gene copies per L)\n')+
theme_classic()+ theme( axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,10)) )

# fig.save("N1vRNA.pdf")
# files.download("N1vRNA.pdf") 
fig7s

# %% [markdown]
# ## Yields by extraction

# %%
a=sample_data
a.weight_vol_extracted_ml=pd.to_numeric(a.weight_vol_extracted_ml)
a=a[~np.isnan(a.RNA_ng_ul_qubit_all)].copy()
a_full=a.copy()

a['mcode']= a["sample_code"].astype('object')
a.loc[a.RNA_yield_quantification=='below quantification limit','mcode'] = "below quantification limit"
a['mcode']=a['mcode'].astype("category")
# a['mcode']=a['mcode'].cat.reorder_categories(['E_INF','milk of silica','ultrafiltration','ultrafiltration and solids', 'below quantification limit'])

fig8s=(ggplot(a, aes(x='weight_vol_extracted_ml', y='RNA_yield_ext', shape='mcode', color='sample_code')) + 
geom_point(size=3, alpha=0.6)+
# facet_grid('~Interceptor')+
xlab('volume of wastewater concentrated (mL)')+
ylab('RNA yield\n(total ng RNA per extraction)')+
# scale_y_log10()+
guides(shape=guide_legend(title=""), color=guide_legend(title=""))+
theme_classic()+ theme( axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )

# fig.save("RNA.pdf")
# files.download("RNA.pdf") 
fig8s

# %%
a=sample_data
a.weight_vol_extracted_ml=pd.to_numeric(a.weight_vol_extracted_ml)
a=a[~np.isnan(a.DNA_ng_ul_qubit_all)].copy()
a_full=a.copy()

a['mcode']= a["sample_code"].astype('object')
a.loc[a.DNA_yield_quantification=='below quantification limit','mcode'] = "below quantification limit"
a['mcode']=a['mcode'].astype("category")
# a['mcode']=a['mcode'].cat.reorder_categories(['E_INF','milk of silica','ultrafiltration','ultrafiltration and solids', 'below quantification limit'])

fig8s=(ggplot(a, aes(x='weight_vol_extracted_ml', y='DNA_yield_ext', shape='mcode', color='sample_code')) + 
geom_point(size=3, alpha=0.6)+
# facet_grid('~Interceptor')+
xlab('volume of wastewater concentrated (mL)')+
ylab('DNA yield\n(total ng RNA per extraction)')+
# scale_y_log10()+
guides(shape=guide_legend(title=""), color=guide_legend(title=""))+
theme_classic()+ theme( axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )

# fig.save("RNA.pdf")
# files.download("RNA.pdf") 
fig8s

# %%
a=sample_data
a.weight_vol_extracted_ml=pd.to_numeric(a.weight_vol_extracted_ml)
a=a[~np.isnan(a.DNA_ng_ul_qubit_all)].copy()
a=a[~np.isnan(a.RNA_ng_ul_qubit_all)].copy()
a_full=a.copy()

a['mcode']= a["sample_code"].astype('object')
a.loc[a.DNA_yield_quantification=='below quantification limit','mcode'] = "below quantification limit"
a['mcode']=a['mcode'].astype("category")
# a['mcode']=a['mcode'].cat.reorder_categories(['E_INF','milk of silica','ultrafiltration','ultrafiltration and solids', 'below quantification limit'])

fig8s=(ggplot(a, aes(x='RNA_yield_ext', y='DNA_yield_ext', shape='mcode', color='sample_code')) + 
geom_point(size=3, alpha=0.6)+
# facet_grid('~Interceptor')+
xlab('RNA yield\n(total ng RNA per extraction)')+
ylab('DNA yield\n(total ng DNA per extraction)')+
# scale_y_log10()+
guides(shape=guide_legend(title=""), color=guide_legend(title=""))+
theme_classic()+ theme( axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )

# fig.save("RNA.pdf")
# files.download("RNA.pdf") 
fig8s

# %%
b=[30, 31, 32]
maxt=grubbs.test(b, alpha=0.9)
# mint=grubbs.min_test_outliers(b, alpha=0.05)
# # outliers=maxt.append(mint)
# # outliers
# mint

# %%
maxt

# %%
grubbs.test(b)

# %% [markdown]
# ## how close are we to the limit for our 1-step RT master mix?

# %%
a=sample_data
a=a[~np.isnan(a.RNA_ng_ul_qubit_all)].copy()
a['height']=-15
a_full=a.copy()



#get biological triplicate inf
a= a.groupby(['sample_code','height']).agg(
                                                                    RNA_mean=('RNA_ng_ul_qubit_all', lambda x: sci.gmean(x,axis=0)),
                                                                    RNA_std=('RNA_ng_ul_qubit_all', lambda x: np.nan if ( len(x) <2 ) else (sci.gstd(x,axis=0))),
                                                                    n=('RNA_ng_ul_qubit_all','count')).reset_index()


#get n=label                                                                   
a['n']='n= '+a['n'].astype('str')
a['ymax']=a.RNA_mean * a.RNA_std
a['ymin']=a.RNA_mean / a.RNA_std

fig8s=(ggplot(a) + 
geom_col(a, aes(x='sample_code', y='RNA_mean',fill='sample_code')) +  
geom_errorbar(a, aes(x='sample_code', y='RNA_mean', ymin='ymin', ymax='ymax'),width=0.2) +
xlab('')+
ylab('RNA yield\n(ng/uL)')+
geom_hline(yintercept=200, color='red')+
geom_text(aes(x = 'sample_code', y = 'height', label='n'),ha='center', va='center')+
theme_classic()+theme( axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )

fig8s

# %%
a=sample_data
a=a[~np.isnan(a.RNA_ng_ul_qubit_all)].copy()
a['height']=-15
a_full=a.copy()



# #get biological triplicate inf
# a= a.groupby(['sample_code','height']).agg(
#                                                                     RNA_mean=('RNA_ng_ul_qubit_all', lambda x: sci.gmean(x,axis=0)),
#                                                                     RNA_std=('RNA_ng_ul_qubit_all', lambda x: np.nan if ( len(x) <2 ) else (sci.gstd(x,axis=0))),
#                                                                     n=('RNA_ng_ul_qubit_all','count')).reset_index()


# #get n=label                                                                   
# a['n']='n= '+a['n'].astype('str')
# a['ymax']=a.RNA_mean * a.RNA_std
# a['ymin']=a.RNA_mean / a.RNA_std

fig8s=(ggplot(a) + 
geom_point(a, aes(x='sample_code', y='RNA_ng_ul_qubit_all',color='sample_code')) +  
# geom_errorbar(a, aes(x='sample_code', y='RNA_mean', ymin='ymin', ymax='ymax'),width=0.2) +
xlab('')+
ylab('RNA yield\n(ng/uL)')+
geom_hline(yintercept=200, color='red')+
geom_hline(yintercept=40, color='blue')+
# geom_text(aes(x = 'sample_code', y = 'height', label='n'),ha='center', va='center')+
theme_classic()+theme( axis_text_x=element_text(rotation=45, hjust=1), figure_size=(4,3)) )

fig8s

# %% [markdown]
# ## Recovery

# %%
# a = get_GFP_recovery(qpcr_averaged) 
qpcr_averaged.GFP_spike_vol_ul.unique()

# %% [markdown]
# ## bCoV extraction experiment

# %%
# merge with sample data
bcov_sd=copy_sd[copy_sd.batch=='B19']
bcov_exp = qpcr_processed.merge(bcov_sd, how='right', left_on='Sample', right_on='sample_id')
bcov_exp.loc[np.isnan(bcov_exp.Quantity_mean)&(bcov_exp.is_undetermined_count==3), "Quantity_mean"]=0

# calculations
bcov_exp['gc_per_L'] = calculate_gc_per_l(bcov_exp) # get gc/L

# %%
a=bcov_exp
# a['height']=-10000
a['height']=0.1
a_full=a.copy()

a

#get biological triplicate inf
a= a.groupby(['sample_code','height']).agg(
                                                                    gc_per_L_mean=('Quantity_mean', lambda x: sci.gmean(x,axis=0)),
                                                                    gc_per_L_std=('Quantity_mean', lambda x: np.nan if ( len(x) <2 ) else (sci.gstd(x,axis=0))),
                                                                    n=('Quantity_mean','count')).reset_index()


#get n=label                                                                   
a['n']='n= '+a['n'].astype('str')
a['ymax']=a.gc_per_L_mean * a.gc_per_L_std
a['ymin']=a.gc_per_L_mean / a.gc_per_L_std


#plot                                                            
fig1=(ggplot(a) + 
geom_col(a, aes(x='sample_code', y='gc_per_L_mean',fill='sample_code')) +   
geom_errorbar(a, aes(x='sample_code', y='gc_per_L_mean', ymin='ymin', ymax='ymax'),width=0.2) +
ylab('log10 concentration\n(Quantity gc/rxn)\n')+
# scale_y_continuous(labels=scientific_format(digits=2))+
scale_y_log10()+
geom_hline(yintercept=100, color='red')+
geom_text( aes(x = 'sample_code', y = 'height',label='n'),ha='center', va='center')+
xlab('')+
theme_classic()+ theme(legend_position='none', axis_text_x=element_text(color='black',rotation=45, hjust=1), axis_text_y=element_text(color='black'),figure_size=(5,3)) )

fig1

# %%
a=bcov_exp
a['height']=-10000
a_full=a.copy()

a

# #get biological triplicate inf
# a= a.groupby(['sample_code','height']).agg(
#                                                                     gc_per_L_mean=('Quantity_mean', lambda x: sci.gmean(x,axis=0)),
#                                                                     gc_per_L_std=('Quantity_mean', lambda x: np.nan if ( len(x) <2 ) else (sci.gstd(x,axis=0))),
#                                                                     n=('Quantity_mean','count')).reset_index()


# #get n=label                                                                   
# a['n']='n= '+a['n'].astype('str')
# a['ymax']=a.gc_per_L_mean * a.gc_per_L_std
# a['ymin']=a.gc_per_L_mean / a.gc_per_L_std


#plot                                                            
fig1=(ggplot(a) + 
geom_point(a, aes(x='sample_code', y='Quantity_mean',color='sample_code')) +   
# geom_errorbar(a, aes(x='sample_code', y='gc_per_L_mean', ymin='ymin', ymax='ymax'),width=0.2) +
ylab('concentration\n(Quantity gc/rxn)\n')+
scale_y_continuous(labels=scientific_format(digits=2))+
# scale_y_log10 ()+
geom_hline(yintercept=100, color='red')+
# geom_text( aes(x = 'sample_code', y = 'height',label='n'),ha='center', va='center')+
xlab('')+
theme_classic()+ theme(legend_position='none', axis_text_x=element_text(color='black',rotation=45, hjust=1), axis_text_y=element_text(color='black'),figure_size=(5,3)) )

fig1

# %% [markdown]
# # GIS and case data

# %% [markdown]
# ## Shape Files

# %% [markdown]
# ### Download shape files

# %%
#shapefile that has geometries for all the sewersheds
mcrs="epsg:3857"
path='/Users/owner/Desktop/Berkeley_Work/data_analysis/sewershed maps/SewageShedFinal/BayAreaSewageSheds.shp'
shapefile = gpd.read_file(path)
shapefile=shapefile.to_crs(mcrs)
shapefile_EBMUD=shapefile.loc[shapefile.Agency=='East Bay MUD (CS & SSOs)']
shapefile_CC=shapefile.loc[shapefile.Agency=='Central Contra Costa Sanitary District']
shapefile_SJ=shapefile.loc[shapefile.Agency=='San Jose City']


#add columns for merging
shapefile['facility']=np.nan
shapefile.loc[shapefile.Agency=='East Bay MUD (CS & SSOs)',"facility"]="EBMUD"
shapefile.facility.unique()

#shapefile with all CA zipcodes and population (TOT_POP)
path='/Users/owner/Desktop/Berkeley_Work/data_analysis/sewershed maps/sewershed_metadata/zip_codes_CA/ZCTA2010.shp'
shapeCA_zip= gpd.read_file(path)
shapeCA_zip=shapeCA_zip.to_crs("epsg:3310")
shapeCA_zip.LATITUDE=shapeCA_zip.LATITUDE.astype('category')
shapeCA_zip.LONGITUDE=shapeCA_zip.LONGITUDE.astype('category')
shapeCA_zip=shapeCA_zip[['geometry','TOT_POP','ZCTA']].copy()
shapeCA_zip=shapeCA_zip.to_crs(mcrs)


#shapefile with A, N, and S within EBMUD
path='/Users/owner/Desktop/Berkeley_Work/data_analysis/sewershed maps/sewershed_maps_EBMUD_ANS/ITA_20101109.shp'
shape_EBMUD_service = gpd.read_file(path)
shape_EBMUD_service=shape_EBMUD_service.to_crs({'init':'EPSG:3310'})
North=["NI01","NI03","AI02","AI01","N05","AF06","N08","N16","N10","N12","N13","N15","N18TAP","N21","N18","N17","N19","N20","N27","N30","N32","N34","N37","N39","N41A"]
Adeline=["ADB","ADC","AD14"]
shape_EBMUD_service=shape_EBMUD_service.copy()
shape_EBMUD_service["Interceptor"]= "S"
shape_EBMUD_service.loc[shape_EBMUD_service.INTID.isin(North),"Interceptor"]="N"
shape_EBMUD_service.loc[shape_EBMUD_service.INTID.isin(Adeline),"Interceptor"]="A"
shape_EBMUD_service=shape_EBMUD_service.to_crs(mcrs)


#dissolve EBMUD interceptor geometries
shapeANS=shape_EBMUD_service.dissolve(by='Interceptor').reset_index()

# %% [markdown]
# ### Make clips

# %%
#overlay of zipcodes and agencies
clip_CC=gpd.clip(shapeCA_zip,shapefile_CC)
clip_EBMUD=gpd.clip(shapeCA_zip,shapefile_EBMUD)
# combo=gpd.overlay(shapefile,clip)

# %% [markdown]
# ## Case Data & weighted average

# %% [markdown]
# ### Download Alameda zipcode case data

# %%
# url = 'https://opendata.arcgis.com/datasets/5d6bf4760af64db48b6d053e7569a47b_3.csv'
# cases_alameda = pd.read_csv(url, low_memory=False)
# cases_alameda=cases_alameda[['dtcreate','ZC_94501', 'ZC_94502', 'ZC_94505', 'ZC_94514', 'ZC_94536', 'ZC_94538',
#        'ZC_94539', 'ZC_94541', 'ZC_94542', 'ZC_94544', 'ZC_94545', 'ZC_94546',
#        'ZC_94550', 'ZC_94551', 'ZC_94552', 'ZC_94555', 'ZC_94560', 'ZC_94566',
#        'ZC_94568', 'ZC_94577', 'ZC_94578', 'ZC_94579', 'ZC_94580', 'ZC_94586',
#        'ZC_94587', 'ZC_94588', 'ZC_94601', 'ZC_94602', 'ZC_94603', 'ZC_94605',
#        'ZC_94606', 'ZC_94607', 'ZC_94608', 'ZC_94609', 'ZC_94610', 'ZC_94611',
#        'ZC_94612', 'ZC_94613', 'ZC_94618', 'ZC_94619', 'ZC_94621', 'ZC_94702',
#        'ZC_94703', 'ZC_94704', 'ZC_94705', 'ZC_94706', 'ZC_94707', 'ZC_94708',
#        'ZC_94709', 'ZC_94710', 'ZC_94720', 'ZC_95377', 'ZC_95391', 'GlobalID',
#        'OBJECTID']].copy()

# cases_alameda.dtcreate=pd.to_datetime(cases_alameda.dtcreate)
# cases_alameda.dtcreate=cases_alameda.dtcreate.dt.date
# cases_alameda=cases_alameda.replace('<10',9) #replacing BDL with 9
# cases_alameda.loc[:, (cases_alameda.columns != 'dtcreate') & (cases_alameda.columns != 'ZCTA') & (cases_alameda.columns != 'OBJECTID')]=cases_alameda.loc[:, (cases_alameda.columns != 'dtcreate' )& (cases_alameda.columns != 'ZCTA')& (cases_alameda.columns != 'OBJECTID')].apply(pd.to_numeric, errors='coerce')
# cases_alameda.index=cases_alameda.dtcreate

# #New cases per day & seven day moving average
# cases_alameda=cases_alameda.drop("dtcreate",axis=1)
# cases_alameda=cases_alameda.diff(periods=1, axis=0).reset_index() #new cases per day
# # cases_alameda_ma7=cases_alameda.rolling('7d', min_periods=5).mean().reset_index() 
# cases_alameda["id"]=cases_alameda.index

# # #convert formatting to mege
# cases_alameda_l=pd.wide_to_long(cases_alameda,['ZC'],i="id", j='ZCTA',sep='_' )
# cases_alameda_l=cases_alameda_l.copy().reset_index()

# cases_alameda_w=cases_alameda_l.pivot(index='ZCTA',columns='dtcreate')[['ZC']].copy().reset_index().droplevel(0, axis=1)
# cases_alameda_w=cases_alameda_w.rename(columns={"": "ZCTA"})
# cases_alameda_l=None

# %%
shapeCA_zip.ZCTA = shapeCA_zip.ZCTA.astype(np.int64)
# shapeCA_zipC=shapeCA_zip.merge(cases_alameda_w,on='ZCTA',how='left').reset_index()
# shapeCA_zipC.TOT_POP=np.float64(shapeCA_zipC.TOT_POP)

# shapeCA_zipC.iloc[:,4:]=shapeCA_zipC.iloc[:,4:].div(shapeCA_zipC.loc[:,"TOT_POP"], axis=0) #include this to normalize by total population by dividing by 2010 census data

# %% [markdown]
# ### Calculate the overlap between each zipcode and each sewershed

# %%
# shape_EBMUD_zipC= gpd.sjoin(shapeCA_zipC,shape_EBMUD_service,how='right',op='intersects').reset_index()

# shape_A= shape_EBMUD_service[shape_EBMUD_service.Interceptor=='A'].dissolve(by='Interceptor').reset_index()
# shape_N= shape_EBMUD_service[shape_EBMUD_service.Interceptor=='N'].dissolve(by='Interceptor').reset_index()
# shape_S= shape_EBMUD_service[shape_EBMUD_service.Interceptor=='S'].dissolve(by='Interceptor').reset_index()

# %% [markdown]
# ### Weight Case data by the overlap

# %%
# #overlay the areas, calculate the area of the overlap and the total area for each zipcode
# inter_A = gpd.overlay(shape_A, shapeCA_zipC)
# inter_A['inter_A'] = inter_A.area #intersection area
# inter_A= pd.DataFrame(inter_A[['ZCTA','inter_A']].copy())

# inter_N = gpd.overlay(shape_N,shapeCA_zipC)
# inter_N['inter_N'] = inter_N.area #intersection area
# inter_N= pd.DataFrame(inter_N[['ZCTA','inter_N']].copy())

# inter_S = gpd.overlay(shape_S,shapeCA_zipC)
# inter_S['inter_S'] = inter_S.area #intersection area
# inter_S= pd.DataFrame(inter_S[['ZCTA','inter_S']].copy())

# inter_all=inter_A.append(inter_N)
# inter_all=inter_all.append(inter_S)
# shapeCA_zipC['tot_area']=shapeCA_zipC.area
# shapeCA_zipC=shapeCA_zipC.merge(inter_all,how='left',on='ZCTA')


# # #calculate the f
# shapeCA_zipC['fr_A']=shapeCA_zipC['inter_A']/shapeCA_zipC['tot_area']
# shapeCA_zipC['fr_N']=shapeCA_zipC['inter_N']/shapeCA_zipC['tot_area']
# shapeCA_zipC['fr_S']=shapeCA_zipC['inter_S']/shapeCA_zipC['tot_area']

# #multiply by A fraction
# shapeCA_zipC_A=shapeCA_zipC.copy()
# shapeCA_zipC_A[shapeCA_zipC_A.select_dtypes([np.float64]).columns]=shapeCA_zipC_A[shapeCA_zipC_A.select_dtypes([np.float64]).columns].multiply(shapeCA_zipC_A['fr_A'], axis='index')
# shapeCA_zipC_A=shapeCA_zipC_A.drop(["ZCTA", "inter_A","inter_N","inter_S","fr_A","fr_N","fr_S","index"],axis=1)
# s_A=pd.DataFrame(shapeCA_zipC_A.sum(axis=0))

# # #multiply by N fraction
# shapeCA_zipC_N=shapeCA_zipC.copy()
# shapeCA_zipC_N[shapeCA_zipC_N.select_dtypes([np.float64]).columns]=shapeCA_zipC_N[shapeCA_zipC_N.select_dtypes([np.float64]).columns].multiply(shapeCA_zipC_N['fr_N'], axis='index')
# shapeCA_zipC_N=shapeCA_zipC_N.drop(["ZCTA", "inter_A","inter_N","inter_S","fr_A","fr_N","fr_S","index"],axis=1)
# s_N=pd.DataFrame(shapeCA_zipC_N.sum(axis=0))


# # #multiply by S fraction
# shapeCA_zipC_S=shapeCA_zipC.copy()
# shapeCA_zipC_S[shapeCA_zipC_S.select_dtypes([np.float64]).columns]=shapeCA_zipC_S[shapeCA_zipC_S.select_dtypes([np.float64]).columns].multiply(shapeCA_zipC_S['fr_S'], axis='index')
# shapeCA_zipC_S=shapeCA_zipC_S.drop(["ZCTA", "inter_A","inter_N","inter_S","fr_A","fr_N","fr_S","index"],axis=1)
# s_S=pd.DataFrame(shapeCA_zipC_S.sum(axis=0))

# %%
# shapeCA_zip= None

# shapeCA_zipC_S=None
# shapeCA_zipC_A=None
# shapeCA_zipC_N=None

# inter_A=None
# inter_N=None
# inter_S=None

# %% [markdown]
# ### Download Contra Costa case data

# %%
#shapefile with all CA counties 
path='/Users/owner/Desktop/Berkeley_Work/data_analysis/sewershed maps/sewershed_metadata/CA_Counties/CA_Counties_TIGER2016.shp'
shapeCA_co = gpd.read_file(path)
shapeCA_co=shapeCA_co.to_crs({'init':'EPSG:3310'})
# shapeCA_co=shapeCA_co[['geometry','NAMELSAD']].copy()
# shapeCA_co.columns=['geometry','c
ounty']
# shapeCA_co=shapeCA_co.to_crs(mcrs)

# shapeCA_sc=shapeCA_co[shapeCA_co.county=="Santa Clara County"].copy()

# %%
# #got it here https://www.coronavirus.cchealth.org/overview
# cases_CC=read_gsheet(gc,qpcr_url, cc_data_tab)
# cases_CC.new_cases=pd.to_numeric(cases_CC.new_cases)
# cases_CC.Date=pd.to_datetime(cases_CC.Date)
# cases_CC.Date=cases_CC.Date.dt.date
# cases_CC=cases_CC[["Date","new_cases",'county']].copy()

# cases_CC_w=cases_CC.pivot(index='county',columns='Date').copy().reset_index().droplevel(0, axis=1)
# cases_CC_w=cases_CC_w.rename(columns={"": "county"})

# cases_CC=None

# %%
# shapeCA_coC=shapeCA_co.merge(cases_CC_w,on='county',how='right').reset_index()

# %%
# shapeCA_co=None

# %% [markdown]
# ### Calculate overlap of Contra Costa with N interceptor

# %%
# # overlay the areas, calculate the area of the overlap
# inter_AC = gpd.overlay(shape_A, shapeCA_coC) #just to check
# inter_SC = gpd.overlay(shape_S,shapeCA_coC) #just to check

# %%
# inter_NC = gpd.overlay(shape_N,shapeCA_coC)
# inter_NCp=inter_NC
# inter_NC['inter_N'] = inter_NC.area #intersection area
# inter_NC= pd.DataFrame(inter_NC[['county','inter_N']].copy())

# %%
# shapeCA_coC=shapeCA_coC.merge(inter_NC,how='left',on='county')
# shapeCA_coC['tot_area']=shapeCA_coC.area

# %%
# shapeCA_coC_N=pd.DataFrame(shapeCA_coC[shapeCA_coC.select_dtypes([np.int64,np.float64]).columns].copy())
# shapeCA_coC_N=shapeCA_coC_N.drop('index', axis=1)
# shapeCA_coC_N['fr_N']=shapeCA_coC_N['inter_N']/shapeCA_coC_N['tot_area']

# %%
# # #multiply by N fraction
# n=["tot_area","inter_NC","fr_N"]
# shapeCA_coC_N.loc[:, ~shapeCA_coC_N.columns.isin(n)]=shapeCA_coC_N.loc[:, ~shapeCA_coC_N.columns.isin(n)] * shapeCA_coC_N.loc[0,'fr_N']

# %%
# no overlap
# df1=shape_S
# df2=shapeCA_coC
# ax=df1.plot(color='red')
# df2.plot(ax=ax)

# %%
# no overlap
# df1=shape_A
# df2=shapeCA_coC
# ax=df1.plot(color='red')
# df2.plot(ax=ax)

# %%
# Overlap with N
# df2=inter_NCp
# df1=shapeCA_coC
# ax=df1.plot()
# df2.plot(ax=ax, color='red')

# %%
# shape_A=None
# shape_N=None
# shape_S=None

# inter_NC=None

# %% [markdown]
# ### Combine

# %%
# # #combine

# #add columns needed & get into same format
# shapeCA_coC_N["TOT_POP"]=0
# s_NC=pd.DataFrame(shapeCA_coC_N.sum(axis=0))
# s_NC.columns=['1']
# s_Np=pd.merge(s_N.reset_index(),s_NC.reset_index())
# s_Np.index=s_Np["index"]
# s_Np=s_Np.drop('index', axis=1)
# s_Np=pd.DataFrame(s_Np.sum(axis=1))

# sumANS=pd.concat([s_A,s_N,s_S],axis=1)
# sumANS.columns=['A','N','S']
# sumANS_T=sumANS.T.reset_index()
# sumANS_T.rename(columns={'index':'Interceptor'}, inplace=True)

# sumANS_T['EBMUD_pop']=[90000, 130000, 465000]

# %%
# shapeCA_coC=None
# shapeCA_coC_N=None

# %%
# a=s_N.reset_index()
# d=['2020-07-14 00:00:00', '2020-07-15 00:00:00','2020-07-16 00:00:00','2020-07-17 00:00:00','2020-07-18 00:00:00','2020-07-19 00:00:00','2020-07-20 00:00:00','2020-07-21 00:00:00']
# a[a['index'].isin(pd.to_datetime(d))]

# %%
# a=s_Np.reset_index()
# a[a['index'].isin(pd.to_datetime(d))]

# %% [markdown]
# ## merge case data with wastewater data

# %%
# shapeANS_C=shapeANS.merge(sumANS_T, how='left',on='Interceptor')
# dfANS_C=shapeANS_C.copy()
# dfANS_C=dfANS_C.drop(['geometry','ITAID','INTID','ACREAGE',	'SURRMID','MID',	'COMMENT','Satellite'	],axis=1)
# dfANS_C=pd.melt(dfANS_C,value_vars=dfANS_C.columns.drop(["Interceptor","TOT_POP",'tot_area',"EBMUD_pop"]),id_vars=["Interceptor","TOT_POP",'tot_area',"EBMUD_pop"], var_name='date',value_name='new_cases_per_day' )
# dfANS_C.date=pd.to_datetime(dfANS_C.date)
# dfANS_C['date_sampling']=dfANS_C['date'].dt.date


# #per population!
# dfANS_C['new_cases_per_person_per_day']=dfANS_C['new_cases_per_day']/dfANS_C['EBMUD_pop']

# dfANS_C['date_sampling']=dfANS_C['date'].dt.date
# qpcr_averaged_merged_copy=qpcr_averaged_merged.copy()
# qpcr_averaged_merged['date_sampling']=pd.to_datetime(qpcr_averaged_merged['date_sampling'])
# qpcr_averaged_merged['date_sampling']=qpcr_averaged_merged['date_sampling'].dt.date
# # qpcr_averaged_merged_copy=qpcr_averaged_merged.copy()
# qpcr_averaged_merged=qpcr_averaged_merged.merge(dfANS_C,how="outer",on=["date_sampling",'interceptor']).reset_index()
# qpcr_averaged_merged.date_sampling=pd.to_datetime(qpcr_averaged_merged.date_sampling)

# %%
# a=qpcr_averaged_merged
# a=a[a.interceptor !="PBS"]
# a=a[(a.Target!='PMMoV')]
# a=a[a.interceptor=='S68']
# a.cases_moving_average=np.log10(a.cases_moving_average)
# a=a[['interceptor','date_sampling', 'Sample','log10_mean_normalized_to_pmmov','cases_moving_average']]
# a=a.melt(id_vars=['Sample','date_sampling'], value_vars=['log10_mean_normalized_to_pmmov','cases_moving_average'], value_name='prev',var_name='var')
# a['var']=a['var'].replace('cases_moving_average','log10(new cases per day in S68 (7 day moving average))')
# a['var']=a['var'].replace('log10_mean_normalized_to_pmmov','normalized SARS-CoV-2 signal  log10 (N1 normalized to PMMoV)')



# fig = (ggplot(a, aes(x='date_sampling', y='prev', color='var')) + 
# geom_point(size=2, alpha = 0.5)+
# geom_line(data=a[~np.isnan(a.prev)])+
# scale_color_manual([case_c,S68_c])+
# ylab('')+
# xlab("")+
# # scale_y_log10(expand=(.1,0))+
# facet_wrap('~var', scales='free_y',nrow=2)+ #, 
# theme_bw()+ theme(axis_text_x=element_text(rotation=45, hjust=1), figure_size=(6,4)) )

# fig

# %%
# a=qpcr_averaged_merged

# a=a[a.plate_id != 48].copy() #removing for now
# a=a[a.date_sampling>pd.to_datetime('2020-04-14')]
# a=a[a.interceptor !="PBS"]
# a=a[(a.Target!='PMMoV')]
# a=a[a.interceptor=='S68']


# a=a[['interceptor','date_sampling', 'Sample','mean_normalized_to_pmmov','cases_moving_average']]
# a=a.melt(id_vars=['Sample','date_sampling'], value_vars=['mean_normalized_to_pmmov','cases_moving_average'], value_name='prev',var_name='var')
# a['var']=a['var'].replace('cases_moving_average','new COVID-19 cases per day in S68 area (7 day moving average)')
# a['var']=a['var'].replace('mean_normalized_to_pmmov','normalized SARS-CoV-2 signal in wastewater from S68 (N1/PMMoV)')
# a['data source']='COVID-19 case data'
# a.loc[(a["var"]=='normalized SARS-CoV-2 signal in wastewater from S68 (N1/PMMoV)'),'data source']='wastewater data'
# l=a['var'].unique()[1]

# fig = (ggplot() + 
# geom_rect( a[a["var"]==l],aes(xmin=pd.to_datetime('2020-07-25'), xmax=pd.to_datetime('2020-08-15'), ymin=0, ymax=150),  color=None,fill = 'pink',alpha = 0.5) +
# geom_point(a,aes(x='date_sampling', y='prev', color='data source'),size=2, alpha = 0.5)+
# geom_line(a[~np.isnan(a.prev)],aes(x='date_sampling', y='prev', color='data source'))+
# geom_smooth(a,aes(x='date_sampling', y='prev'),linetype = 'dashed', method = "loess")+
# scale_color_manual([case_c,S68_c])+
# ylab('')+
# xlab("")+
# # scale_y_log10(expand=(.1,0))+
# facet_wrap('~var', scales='free_y',nrow=2)+ #, 
# theme_classic()+ theme(axis_text_x=element_text(rotation=45, hjust=1, color='black'), axis_text_y=element_text( color='black'),figure_size=(5.5,4)) )



# # fig.save("proof_of_concept.pdf")
# # files.download("proof_of_concept.pdf") 

# fig

# %%
# a = shapefile.to_crs(mcrs)
# a["rep"] = a["geometry"].representative_point()
# za_points = a.copy()
# za_points.set_geometry("rep", inplace = True)

# ax = a.plot( column='Agency',legend=True,  figsize=(20,20), cmap= mplt.get_cmap('tab20c'), alpha=0.8, edgecolor='k')
# leg = ax.get_legend ()
# leg.set_bbox_to_anchor ((1.5, 1))
# texts = []
# # for x, y, label in zip(za_points.geometry.x, za_points.geometry.y, za_points["facility"]):
# #     texts.append(plt.text(x, y, label, fontsize = 20))
    

# # aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
# #                arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
# ctx.add_basemap(ax)



# # mplt.savefig("agencies_map.pdf")
# # files.download("agencies_map.pdf")

# %%
a = shapefile.to_crs(epsg=3857)
n=1
county=a.County_1.unique()
a=a[a.County_1==county[n]]
a["rep"] = a["geometry"].representative_point()
za_points = a.copy()
za_points.set_geometry("rep", inplace = True)


ax = a.plot( column='Agency',legend=True,  figsize=(15,10), cmap= mplt.get_cmap('tab20c'), alpha=0.8, edgecolor='k')
mplt.title(county[n])
leg = ax.get_legend ()

leg.set_bbox_to_anchor ((1, 1))
texts = []
# for x, y, label in zip(za_points.geometry.x, za_points.geometry.y, za_points["facility"]):
#     texts.append(plt.text(x, y, label, fontsize = 20))
    

# aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
#                arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
ctx.add_basemap(ax)
name=county[n]+'.pdf'
# mplt.savefig(name)
# files.download(name)

# %%
# import matplotlib.dates as mdates
# import matplotlib.cbook as cbook

# years = mdates.YearLocator()   # every year
# months = mdates.MonthLocator()  # every month
# days = mdates.DayLocator()  # every day
# # years_fmt = mdates.DateFormatter('%Y')

# a=qpcr_averaged_merged
# a=a[a.interceptor !="PBS"]
# a=a[a.Target=='N1']
# a=a[a.interceptor=='S68']

# data1 = "mean_normalized_to_pmmov"
# data2 = "cases_moving_average"

# fig, ax1 = mplt.subplots()

# color = 'tab:red'
# ax1.set_xlabel('')
# ax1.set_ylabel('normalized SARS-CoV-2 signal \nlog10(N1 normalized to PMMoV)', color=color)
# ax1.plot('date_sampling', data1, 'ro-',data=a)
# # ax1.tick_params(axis='y', labelcolor=color)

# # # format the ticks
# # ax1.xaxis.set_major_locator(months)
# # # ax1.xaxis.set_major_formatter(years_fmt)
# # ax1.xaxis.set_minor_locator(days)

# # # format the coords message box
# # ax1.format_xdata = mdates.DateFormatter('%Y-%m-%d')

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:blue'
# ax2.set_ylabel('daily cumulative cases normalized by area', color=color)  # we already handled the x-label with ax1
# ax2.plot('date_sampling', data2,data=a, color=color, marker='o')
# ax2.tick_params(axis='y', labelcolor=color)

# fig.tight_layout()  # otherwise the right y-label is slightly clipped
# fig.autofmt_xdate()
# mplt.show()

# %%
# versions of packages
# !pip freeze

# %% [markdown]
# # colors

# %%
ADA_c="#453781"
S68_c="#287D8E"
N49_c= "#3CBB75"
case_c="#DCE319"
case2_c="#55C667"

ami_c="#782B9D"
colh_c="#C0369D"
col_c="#ED5983"
mos_c= "#F89078"

sal_c='#023E73'
fresh='#A69B7B'
nos_c='#D9BE6C'

pmmov_c='#5DD959'
N1_c='#D95959'
bcov_c='#5D59D9'

# %% [markdown]
# # EBMUD service area

# %%
a = shapeANS#.to_crs(epsg=3857)
a["rep"] = a["geometry"].representative_point()
za_points = a.copy()
za_points.set_geometry("rep", inplace = True)

ax = a.plot(color=[ADA_c,N49_c, S68_c], legend=False,  figsize=(10,10), alpha=0.3, edgecolor='k', )
texts = []
for x, y, label in zip(za_points.geometry.x, za_points.geometry.y, za_points["Interceptor"]):
    texts.append(mplt.text(x, y, label, fontsize = 20))
    

aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
               arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
fig=ctx.add_basemap(ax)

#title for the plot
n='EBMUD' 
plot1=n  +'.pdf'
#path for the plot
path=os.path.join(dir_c, plot1)
#save the plot


# mplt.savefig(path)

# %% [markdown]
# # Overlap between San Jose sewershed and city/county

# %%
shapefile_SJ.crs

# %%
shapeCA_sc.crs

# %%
ax = shapeCA_sc.plot(color='gray', alpha=0.5,edgecolor='black',figsize=[12,16])
shapefile_SJ.plot(ax=ax,  cmap='summer', legend=True,
                          edgecolor='black', linewidth=0.4, alpha=0.8)
ax.set_title('San Jose Sewershed in Santa Clara County', size=18);
fig=ctx.add_basemap(ax)

plot="San_Jose_Sewershed.pdf"
path=os.path.join(dir_l, plot)
mplt.savefig(path)

fig

# %%
plot="San_Jose_sewershed.shp"
path=os.path.join(dir_l, plot)
shapefile_SJ.to_file(path)

# %% [markdown]
# # Zipcodes in each interceptor by county

# %%
#use this to plot by county

#  a = shapefile
# n=1
# county=a.County_1.unique()
# a=a[a.County_1==county[n]]
# a["rep"] = a["geometry"].representative_point()
# za_points = a.copy()
# za_points.set_geometry("rep", inplace = True)


# ax = a.plot( column='Agency',legend=True,  figsize=(15,10), cmap= mplt.get_cmap('tab20c'), alpha=0.8, edgecolor='k')
# mplt.title(county[n])
# leg = ax.get_legend ()

# leg.set_bbox_to_anchor ( (1, 1))
# texts = []
# # for x, y, label in zip(za_points.geometry.x, za_points.geometry.y, za_points["facility"]):
# #     texts.append(plt.text(x, y, label, fontsize = 20))
    

# # aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
# #                arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
# ctx.add_basemap(ax)
# name=county[n]+'.pdf'
# mplt.savefig(path)
# files.download("EBMUD_map.png")

# %%
a=clip_EBMUD

a["rep"] = a["geometry"].representative_point()
za_points = a.copy()
za_points.set_geometry("rep", inplace = True)
title='EBMUD service area and connected zip codes'

ax = a.plot( column='ZCTA',legend=False,  figsize=(15,10), cmap= mplt.get_cmap('tab20c'), alpha=0.8, edgecolor='k')
mplt.title(title)
leg = ax.get_legend ()

# leg.set_bbox_to_anchor ( (1, 1))
texts = []
for x, y, label in zip(za_points.geometry.x, za_points.geometry.y, za_points["ZCTA"]):
    texts.append(mplt.text(x, y, label, fontsize = 12))
    

aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
               arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
ctx.add_basemap(ax)
name='EBMUD_zip'+'.pdf'
path=os.path.join(dir_c, name)
mplt.savefig(path)

# %%
a=clip_CC

a["rep"] = a["geometry"].representative_point()
za_points = a.copy()
za_points.set_geometry("rep", inplace = True)
title='Central Contra Costa Sanitary District service area and connected zip codes'

ax = a.plot( column='ZCTA',legend=False,  figsize=(15,10), cmap= mplt.get_cmap('tab20c'), alpha=0.8, edgecolor='k')
mplt.title(title)
leg = ax.get_legend ()

# leg.set_bbox_to_anchor ( (1, 1))
texts = []
for x, y, label in zip(za_points.geometry.x, za_points.geometry.y, za_points["ZCTA"]):
    texts.append(mplt.text(x, y, label, fontsize = 12))
    

aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
               arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
ctx.add_basemap(ax)
name='contra_costa_zip'+'.pdf'
path=os.path.join(dir_c, name)
mplt.savefig(path)
